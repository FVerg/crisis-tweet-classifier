# %%
import nltk
import pandas as pd

pd.options.mode.chained_assignment = None

def pos_tweet(tweet):
    pos = nltk.sent_tokenize(tweet)
    pos = [nltk.word_tokenize(sent) for sent in pos]
    pos = [nltk.pos_tag(sent) for sent in pos]
    return pos


dataset = pd.read_csv('C:/dataset/2013_pakistan_eq.csv', header=0)


dataset.set_index('tweet_id')

tweet_ids = dataset['tweet_id']
tweet_texts = dataset['tweet_text']

for i in range(0, tweet_ids.size):
    tweet_ids[i] = tweet_ids[i].replace("'", "")

tagged_tweets = []

for id, text in zip(tweet_ids, tweet_texts):
    tagged_tweets.append({"TweetID": id, "Text": text, "POS": pos_tweet(text)})

# %%
tagged_tweets
# Out:
# [{'TweetID': '382813388503412736',
#   'Text': 'USGS reports a M1.7 #earthquake 70km ESE of Healy, Alaska on 9/28/13 @ 2:45:15 UTC http://t.co/MQkCfKZisl #quake',
#   'POS': [[('USGS', 'NNP'),
#     ('reports', 'VBZ'),
#     ('a', 'DT'),
#     ('M1.7', 'NNP'),
#     ('#', '#'),
#     ('earthquake', 'NN'),
#     ('70km', 'CD'),
#     ('ESE', 'NNP'),
#     ('of', 'IN'),
#     ('Healy', 'NNP'),
#     (',', ','),
#     ('Alaska', 'NNP'),
#     ('on', 'IN'),
#     ('9/28/13', 'CD'),
#     ('@', 'JJ'),
#     ('2:45:15', 'CD'),
#     ('UTC', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/MQkCfKZisl', 'JJ'),
#     ('#', '#'),
#     ('quake', 'NN')]]},
#  {'TweetID': '382813391435206659',
#   'Text': 'QuakeFactor M 3.0, Southern Alaska: Sunday, September 29, 2013 21:15:20 UTCSunday, Septemb... http://t.co/edtau43Co2 #earthquake, #quake',
#   'POS': [[('QuakeFactor', 'NNP'),
#     ('M', 'NNP'),
#     ('3.0', 'CD'),
#     (',', ','),
#     ('Southern', 'NNP'),
#     ('Alaska', 'NNP'),
#     (':', ':'),
#     ('Sunday', 'NNP'),
#     (',', ','),
#     ('September', 'NNP'),
#     ('29', 'CD'),
#     (',', ','),
#     ('2013', 'CD'),
#     ('21:15:20', 'CD'),
#     ('UTCSunday', 'NNP'),
#     (',', ','),
#     ('Septemb', 'NNP'),
#     ('...', ':'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/edtau43Co2', 'JJ'),
#     ('#', '#'),
#     ('earthquake', 'NN'),
#     (',', ','),
#     ('#', '#'),
#     ('quake', 'NN')]]},
#  {'TweetID': '382813401845485568',
#   'Text': 'What you wanna say abt #TTP #PeaceTalks &amp; #Pakistan ??? Call now &amp; #LetsTalk to RJ @ubaid_imran Live Now Insaf... http://t.co/tUAIo0krST',
#   'POS': [[('What', 'WP'),
#     ('you', 'PRP'),
#     ('wan', 'VBP'),
#     ('na', 'NNS'),
#     ('say', 'VBP'),
#     ('abt', 'JJ'),
#     ('#', '#'),
#     ('TTP', 'NNP'),
#     ('#', '#'),
#     ('PeaceTalks', 'NNP'),
#     ('&', 'CC'),
#     ('amp', 'NN'),
#     (';', ':'),
#     ('#', '#'),
#     ('Pakistan', 'NNP'),
#     ('?', '.'),
#     ('?', '.'),
#     ('?', '.')],
#    [('Call', 'NN'),
#     ('now', 'RB'),
#     ('&', 'CC'),
#     ('amp', 'RB'),
#     (';', ':'),
#     ('#', '#'),
#     ('LetsTalk', 'NNP'),
#     ('to', 'TO'),
#     ('RJ', 'NNP'),
#     ('@', 'NNP'),
#     ('ubaid_imran', 'JJ'),
#     ('Live', 'NNP'),
#     ('Now', 'RB'),
#     ('Insaf', 'NNP'),
#     ('...', ':'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/tUAIo0krST', 'NN')]]},
#  {'TweetID': '382813437513834497',
#   'Text': 'Top Story: Pakistan quake survivors face long wait for aid: Awaran (Pakistan)- Tens of thousan... http://t.co/Cd6SYLXs5f #pakistan #news',
#   'POS': [[('Top', 'JJ'),
#     ('Story', 'NN'),
#     (':', ':'),
#     ('Pakistan', 'NNP'),
#     ('quake', 'NN'),
#     ('survivors', 'NNS'),
#     ('face', 'VBP'),
#     ('long', 'JJ'),
#     ('wait', 'NN'),
#     ('for', 'IN'),
#     ('aid', 'NN'),
#     (':', ':'),
#     ('Awaran', 'NNP'),
#     ('(', '('),
#     ('Pakistan', 'NNP'),
#     (')', ')'),
#     ('-', ':'),
#     ('Tens', 'NNS'),
#     ('of', 'IN'),
#     ('thousan', 'NN'),
#     ('...', ':'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/Cd6SYLXs5f', 'JJ'),
#     ('#', '#'),
#     ('pakistan', 'JJ'),
#     ('#', '#'),
#     ('news', 'NN')]]},
#  {'TweetID': '382813440655376384',
#   'Text': 'RT @SaimaMohsin: 264 dead, more than 400 injured in 7.7 magnitude quake very close to surface - #Awaran #Balochistan worst affected',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('SaimaMohsin', 'NNP'),
#     (':', ':'),
#     ('264', 'CD'),
#     ('dead', 'JJ'),
#     (',', ','),
#     ('more', 'JJR'),
#     ('than', 'IN'),
#     ('400', 'CD'),
#     ('injured', 'JJ'),
#     ('in', 'IN'),
#     ('7.7', 'CD'),
#     ('magnitude', 'JJ'),
#     ('quake', 'NN'),
#     ('very', 'RB'),
#     ('close', 'RB'),
#     ('to', 'TO'),
#     ('surface', 'VB'),
#     ('-', ':'),
#     ('#', '#'),
#     ('Awaran', 'NNP'),
#     ('#', '#'),
#     ('Balochistan', 'NNP'),
#     ('worst', 'RB'),
#     ('affected', 'VBD')]]},
#  {'TweetID': '382813444011204608',
#   'Text': 'USGS reports a M1.2 #earthquake 6km SSE of San Juan Bautista, California on 9/27/13 @ 21:36:47 UTC http://t.co/ZBpGpA5kNE #quake',
#   'POS': [[('USGS', 'NNP'),
#     ('reports', 'VBZ'),
#     ('a', 'DT'),
#     ('M1.2', 'NNP'),
#     ('#', '#'),
#     ('earthquake', 'NN'),
#     ('6km', 'CD'),
#     ('SSE', 'NNP'),
#     ('of', 'IN'),
#     ('San', 'NNP'),
#     ('Juan', 'NNP'),
#     ('Bautista', 'NNP'),
#     (',', ','),
#     ('California', 'NNP'),
#     ('on', 'IN'),
#     ('9/27/13', 'CD'),
#     ('@', 'JJ'),
#     ('21:36:47', 'CD'),
#     ('UTC', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/ZBpGpA5kNE', 'JJ'),
#     ('#', '#'),
#     ('quake', 'NN')]]},
#  {'TweetID': '382813445495586816',
#   'Text': 'RT @ErumManzoor: Island that emerged near Gwadar #earthquake is temporary, say experts. Hmmm.  How about setting up a TTP office there? viaâ€¦',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('ErumManzoor', 'NNP'),
#     (':', ':'),
#     ('Island', 'NN'),
#     ('that', 'IN'),
#     ('emerged', 'VBD'),
#     ('near', 'IN'),
#     ('Gwadar', 'NNP'),
#     ('#', '#'),
#     ('earthquake', 'NN'),
#     ('is', 'VBZ'),
#     ('temporary', 'JJ'),
#     (',', ','),
#     ('say', 'VB'),
#     ('experts', 'NNS'),
#     ('.', '.')],
#    [('Hmmm', 'NNP'), ('.', '.')],
#    [('How', 'WRB'),
#     ('about', 'RB'),
#     ('setting', 'VBG'),
#     ('up', 'RP'),
#     ('a', 'DT'),
#     ('TTP', 'NNP'),
#     ('office', 'NN'),
#     ('there', 'RB'),
#     ('?', '.')],
#    [('viaâ€¦', 'NN')]]},
#  {'TweetID': '382813466014121984',
#   'Text': '@AQpk 1300+ People have been killed due to terrorism in last 15 weeks. http://t.co/vwUGXigs6p  #OverthrowCorruptSystem #Pakistan',
#   'POS': [[('@', 'JJ'),
#     ('AQpk', 'NNP'),
#     ('1300+', 'CD'),
#     ('People', 'NNS'),
#     ('have', 'VBP'),
#     ('been', 'VBN'),
#     ('killed', 'VBN'),
#     ('due', 'JJ'),
#     ('to', 'TO'),
#     ('terrorism', 'NN'),
#     ('in', 'IN'),
#     ('last', 'JJ'),
#     ('15', 'CD'),
#     ('weeks', 'NNS'),
#     ('.', '.')],
#    [('http', 'NN'),
#     (':', ':'),
#     ('//t.co/vwUGXigs6p', 'JJ'),
#     ('#', '#'),
#     ('OverthrowCorruptSystem', 'NNP'),
#     ('#', '#'),
#     ('Pakistan', 'NNP')]]},
#  {'TweetID': '382813467528282112',
#   'Text': 'Quetta quake toll 328, more deaths feared http://t.co/RQYwYjUnxh #Karachi #Pakistan',
#   'POS': [[('Quetta', 'NNP'),
#     ('quake', 'NN'),
#     ('toll', 'NN'),
#     ('328', 'CD'),
#     (',', ','),
#     ('more', 'JJR'),
#     ('deaths', 'NNS'),
#     ('feared', 'VBN'),
#     ('http', 'NNS'),
#     (':', ':'),
#     ('//t.co/RQYwYjUnxh', 'RB'),
#     ('#', '#'),
#     ('Karachi', 'NNP'),
#     ('#', '#'),
#     ('Pakistan', 'NNP')]]},
#  {'TweetID': '382813501489946624',
#   'Text': 'RT @RT_com: Update: Death toll in #Peshawar bomb blast rises to 38, about 100 injured - hospital officials http://t.co/N4phtjDGk8 #Pakistan',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('RT_com', 'NNP'),
#     (':', ':'),
#     ('Update', 'NN'),
#     (':', ':'),
#     ('Death', 'NNP'),
#     ('toll', 'NN'),
#     ('in', 'IN'),
#     ('#', '#'),
#     ('Peshawar', 'NNP'),
#     ('bomb', 'NN'),
#     ('blast', 'NN'),
#     ('rises', 'VBZ'),
#     ('to', 'TO'),
#     ('38', 'CD'),
#     (',', ','),
#     ('about', 'RB'),
#     ('100', 'CD'),
#     ('injured', 'JJ'),
#     ('-', ':'),
#     ('hospital', 'NN'),
#     ('officials', 'NNS'),
#     ('http', 'VBD'),
#     (':', ':'),
#     ('//t.co/N4phtjDGk8', 'NN'),
#     ('#', '#'),
#     ('Pakistan', 'NNP')]]},
#  {'TweetID': '382813501729017856',
#   'Text': '#Earthquake M 2.1, Northern California http://t.co/90COqYKVRf',
#   'POS': [[('#', '#'),
#     ('Earthquake', 'NNP'),
#     ('M', 'NNP'),
#     ('2.1', 'CD'),
#     (',', ','),
#     ('Northern', 'NNP'),
#     ('California', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/90COqYKVRf', 'NN')]]},
#  {'TweetID': '382813514881982464',
#   'Text': 'RT @CNBCPAKISTAN: Ch. Nisar: Rockets were fired at a rescue and relief helicopter when it tried to access #earthquake victims in #Balochistâ€¦',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('CNBCPAKISTAN', 'NNP'),
#     (':', ':'),
#     ('Ch', 'NNP'),
#     ('.', '.')],
#    [('Nisar', 'NN'),
#     (':', ':'),
#     ('Rockets', 'NNS'),
#     ('were', 'VBD'),
#     ('fired', 'VBN'),
#     ('at', 'IN'),
#     ('a', 'DT'),
#     ('rescue', 'NN'),
#     ('and', 'CC'),
#     ('relief', 'NN'),
#     ('helicopter', 'NN'),
#     ('when', 'WRB'),
#     ('it', 'PRP'),
#     ('tried', 'VBD'),
#     ('to', 'TO'),
#     ('access', 'NN'),
#     ('#', '#'),
#     ('earthquake', 'NN'),
#     ('victims', 'NNS'),
#     ('in', 'IN'),
#     ('#', '#'),
#     ('Balochistâ€¦', 'NNP')]]},
#  {'TweetID': '382813518602313729',
#   'Text': 'Azerbaijani Ministry of Emergency Situations offered to #Pakistan to hold rescue operations in the quake-hit regions http://t.co/rlrOxB65s6',
#   'POS': [[('Azerbaijani', 'NNP'),
#     ('Ministry', 'NNP'),
#     ('of', 'IN'),
#     ('Emergency', 'NNP'),
#     ('Situations', 'NNP'),
#     ('offered', 'VBD'),
#     ('to', 'TO'),
#     ('#', '#'),
#     ('Pakistan', 'NNP'),
#     ('to', 'TO'),
#     ('hold', 'VB'),
#     ('rescue', 'NN'),
#     ('operations', 'NNS'),
#     ('in', 'IN'),
#     ('the', 'DT'),
#     ('quake-hit', 'JJ'),
#     ('regions', 'NNS'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/rlrOxB65s6', 'NN')]]},
#  {'TweetID': '382813530396700672',
#   'Text': "RT @RT_com: PHOTO: #NASA releases image of #Pakistan's 'Earthquake Island' http://t.co/aBHdfEFZEl http://t.co/iwEFUiequ1",
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('RT_com', 'NNP'),
#     (':', ':'),
#     ('PHOTO', 'NN'),
#     (':', ':'),
#     ('#', '#'),
#     ('NASA', 'NNP'),
#     ('releases', 'VBZ'),
#     ('image', 'NN'),
#     ('of', 'IN'),
#     ('#', '#'),
#     ('Pakistan', 'NNP'),
#     ("'s", 'POS'),
#     ("'Earthquake", 'NNP'),
#     ('Island', 'NNP'),
#     ("'", 'POS'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/aBHdfEFZEl', 'JJ'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/iwEFUiequ1', 'NN')]]},
#  {'TweetID': '382813532305096705',
#   'Text': '#earthquake: M 1.0, Northern California http://t.co/6RRJuGEgb7',
#   'POS': [[('#', '#'),
#     ('earthquake', 'NN'),
#     (':', ':'),
#     ('M', 'NNP'),
#     ('1.0', 'CD'),
#     (',', ','),
#     ('Northern', 'NNP'),
#     ('California', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/6RRJuGEgb7', 'NN')]]},
#  {'TweetID': '382813540366954497',
#   'Text': 'RT @VincentTongue: #Peru  #earthquake M6.8M, Depth:33km   25 Sep 2013 16:42UTC   About 14191 people within 100km http://t.co/cC0ICGysLX',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('VincentTongue', 'NNP'),
#     (':', ':'),
#     ('#', '#'),
#     ('Peru', 'NNP'),
#     ('#', '#'),
#     ('earthquake', 'NN'),
#     ('M6.8M', 'NNP'),
#     (',', ','),
#     ('Depth:33km', 'NNP'),
#     ('25', 'CD'),
#     ('Sep', 'NNP'),
#     ('2013', 'CD'),
#     ('16:42UTC', 'CD'),
#     ('About', 'IN'),
#     ('14191', 'CD'),
#     ('people', 'NNS'),
#     ('within', 'IN'),
#     ('100km', 'CD'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/cC0ICGysLX', 'NN')]]},
#  {'TweetID': '382813540413095936',
#   'Text': 'RT @FoxNews: #Pakistan militants fire on quake relief helicopter, as death toll rises to 348: http://t.co/avePx9rEAU',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('FoxNews', 'NNP'),
#     (':', ':'),
#     ('#', '#'),
#     ('Pakistan', 'NNP'),
#     ('militants', 'NNS'),
#     ('fire', 'NN'),
#     ('on', 'IN'),
#     ('quake', 'NN'),
#     ('relief', 'NN'),
#     ('helicopter', 'NN'),
#     (',', ','),
#     ('as', 'IN'),
#     ('death', 'NN'),
#     ('toll', 'NN'),
#     ('rises', 'VBZ'),
#     ('to', 'TO'),
#     ('348', 'CD'),
#     (':', ':'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/avePx9rEAU', 'NN')]]},
#  {'TweetID': '382813561875361792',
#   'Text': 'RT @Fahdhusain: 11 kids recovered alive from under earthquake rubble in Awaran. Shukar Allah!! #earthquake',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('Fahdhusain', 'NNP'),
#     (':', ':'),
#     ('11', 'CD'),
#     ('kids', 'NNS'),
#     ('recovered', 'VBD'),
#     ('alive', 'JJ'),
#     ('from', 'IN'),
#     ('under', 'IN'),
#     ('earthquake', 'NN'),
#     ('rubble', 'NN'),
#     ('in', 'IN'),
#     ('Awaran', 'NNP'),
#     ('.', '.')],
#    [('Shukar', 'NNP'), ('Allah', 'NNP'), ('!', '.'), ('!', '.')],
#    [('#', '#'), ('earthquake', 'NN')]]},
#  {'TweetID': '382813565054226432',
#   'Text': 'RT @allaboutmqm: News: #MQM Quaid Altaf Hussain Voices Concern Over Murderous Attempt On Prof Nabiâ€™s Life #Karachi #Pakistan http://t.co/28â€¦',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('allaboutmqm', 'NN'),
#     (':', ':'),
#     ('News', 'NN'),
#     (':', ':'),
#     ('#', '#'),
#     ('MQM', 'NNP'),
#     ('Quaid', 'NNP'),
#     ('Altaf', 'NNP'),
#     ('Hussain', 'NNP'),
#     ('Voices', 'NNS'),
#     ('Concern', 'NNP'),
#     ('Over', 'NNP'),
#     ('Murderous', 'NNP'),
#     ('Attempt', 'NNP'),
#     ('On', 'IN'),
#     ('Prof', 'NNP'),
#     ('Nabiâ€™s', 'NNP'),
#     ('Life', 'NNP'),
#     ('#', '#'),
#     ('Karachi', 'NNP'),
#     ('#', '#'),
#     ('Pakistan', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/28â€¦', 'NN')]]},
#  {'TweetID': '382813569597071360',
#   'Text': 'RT @AWAIS_NIAZI1: #KPKUpdates: 2 @ISFPakistan boys injured in firing on replacing #ANP flag wth #Pakistan on clg building. #Saramnaak http:â€¦',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('AWAIS_NIAZI1', 'NNP'),
#     (':', ':'),
#     ('#', '#'),
#     ('KPKUpdates', 'NNS'),
#     (':', ':'),
#     ('2', 'CD'),
#     ('@', 'NN'),
#     ('ISFPakistan', 'NNP'),
#     ('boys', 'VBZ'),
#     ('injured', 'VBN'),
#     ('in', 'IN'),
#     ('firing', 'VBG'),
#     ('on', 'IN'),
#     ('replacing', 'VBG'),
#     ('#', '#'),
#     ('ANP', 'NNP'),
#     ('flag', 'NN'),
#     ('wth', 'NN'),
#     ('#', '#'),
#     ('Pakistan', 'NNP'),
#     ('on', 'IN'),
#     ('clg', 'NN'),
#     ('building', 'NN'),
#     ('.', '.')],
#    [('#', '#'),
#     ('Saramnaak', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('â€¦', 'NN')]]},
#  {'TweetID': '382813587410259968',
#   'Text': 'Awaran mn 312 dead,, Keich mn 44 dead..:( #Balochistan #earthquake',
#   'POS': [[('Awaran', 'NNP'),
#     ('mn', 'VBD'),
#     ('312', 'CD'),
#     ('dead', 'JJ'),
#     (',', ','),
#     (',', ','),
#     ('Keich', 'NNP'),
#     ('mn', 'VBD'),
#     ('44', 'CD'),
#     ('dead..', 'NN'),
#     (':', ':'),
#     ('(', '('),
#     ('#', '#'),
#     ('Balochistan', 'NNP'),
#     ('#', '#'),
#     ('earthquake', 'NN')]]},
#  {'TweetID': '382813601024995328',
#   'Text': 'RT @allaboutmqm: News: This is the time of the need we must help the affected people of #Balochistan: @MQMUSA #MQM #Pakistan http://t.co/HQâ€¦',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('allaboutmqm', 'NN'),
#     (':', ':'),
#     ('News', 'NN'),
#     (':', ':'),
#     ('This', 'DT'),
#     ('is', 'VBZ'),
#     ('the', 'DT'),
#     ('time', 'NN'),
#     ('of', 'IN'),
#     ('the', 'DT'),
#     ('need', 'NN'),
#     ('we', 'PRP'),
#     ('must', 'MD'),
#     ('help', 'VB'),
#     ('the', 'DT'),
#     ('affected', 'JJ'),
#     ('people', 'NNS'),
#     ('of', 'IN'),
#     ('#', '#'),
#     ('Balochistan', 'NNP'),
#     (':', ':'),
#     ('@', 'JJ'),
#     ('MQMUSA', 'NNP'),
#     ('#', '#'),
#     ('MQM', 'NNP'),
#     ('#', '#'),
#     ('Pakistan', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/HQâ€¦', 'NN')]]},
#  {'TweetID': '382813620356534272',
#   'Text': 'RT @Chiltan: she is waiting for your help #Awaran girl child #BalochistanEarthquake  http://t.co/jlzN8iMrOx',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('Chiltan', 'NNP'),
#     (':', ':'),
#     ('she', 'PRP'),
#     ('is', 'VBZ'),
#     ('waiting', 'VBG'),
#     ('for', 'IN'),
#     ('your', 'PRP$'),
#     ('help', 'NN'),
#     ('#', '#'),
#     ('Awaran', 'NNP'),
#     ('girl', 'FW'),
#     ('child', 'NN'),
#     ('#', '#'),
#     ('BalochistanEarthquake', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/jlzN8iMrOx', 'NN')]]},
#  {'TweetID': '382813652752928768',
#   'Text': "RT @DrAwab: 250+ people have been killed in #Balochistan didn't we have a Chief Minister there? Missing? Abducted? Or has he gone island hoâ€¦",
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('DrAwab', 'NNP'),
#     (':', ':'),
#     ('250+', 'CD'),
#     ('people', 'NNS'),
#     ('have', 'VBP'),
#     ('been', 'VBN'),
#     ('killed', 'VBN'),
#     ('in', 'IN'),
#     ('#', '#'),
#     ('Balochistan', 'NNP'),
#     ('did', 'VBD'),
#     ("n't", 'RB'),
#     ('we', 'PRP'),
#     ('have', 'VBP'),
#     ('a', 'DT'),
#     ('Chief', 'JJ'),
#     ('Minister', 'NNP'),
#     ('there', 'EX'),
#     ('?', '.')],
#    [('Missing', 'VBG'), ('?', '.')],
#    [('Abducted', 'VBN'), ('?', '.')],
#    [('Or', 'CC'),
#     ('has', 'VBZ'),
#     ('he', 'PRP'),
#     ('gone', 'VBN'),
#     ('island', 'NN'),
#     ('hoâ€¦', 'NN')]]},
#  {'TweetID': '382813700375474176',
#   'Text': 'Just Shocking #News #Earthquake in #Pakistan #st... http://t.co/SiDBPiGwbT',
#   'POS': [[('Just', 'RB'),
#     ('Shocking', 'VBG'),
#     ('#', '#'),
#     ('News', 'NNP'),
#     ('#', '#'),
#     ('Earthquake', 'NNP'),
#     ('in', 'IN'),
#     ('#', '#'),
#     ('Pakistan', 'NNP'),
#     ('#', '#'),
#     ('st', 'NN'),
#     ('...', ':'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/SiDBPiGwbT', 'NN')]]},
#  {'TweetID': '382813702132867072',
#   'Text': '#NASA Releases Images of #Earthquake Island off Coast of #Pakistan,  Zalzala #Jazeera: http://t.co/hKoJPHA9Xc  #EarthChanges',
#   'POS': [[('#', '#'),
#     ('NASA', 'NNP'),
#     ('Releases', 'NNP'),
#     ('Images', 'NNP'),
#     ('of', 'IN'),
#     ('#', '#'),
#     ('Earthquake', 'NNP'),
#     ('Island', 'NNP'),
#     ('off', 'IN'),
#     ('Coast', 'NNP'),
#     ('of', 'IN'),
#     ('#', '#'),
#     ('Pakistan', 'NNP'),
#     (',', ','),
#     ('Zalzala', 'NNP'),
#     ('#', '#'),
#     ('Jazeera', 'NNP'),
#     (':', ':'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/hKoJPHA9Xc', 'JJ'),
#     ('#', '#'),
#     ('EarthChanges', 'NNS')]]},
#  {'TweetID': '382813719941484544',
#   'Text': '#earthquake: M 1.9, Island of Hawaii, Hawaii http://t.co/MwWyOEaHvx',
#   'POS': [[('#', '#'),
#     ('earthquake', 'NN'),
#     (':', ':'),
#     ('M', 'NNP'),
#     ('1.9', 'CD'),
#     (',', ','),
#     ('Island', 'NNP'),
#     ('of', 'IN'),
#     ('Hawaii', 'NNP'),
#     (',', ','),
#     ('Hawaii', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/MwWyOEaHvx', 'NN')]]},
#  {'TweetID': '382813733623300096',
#   'Text': 'Khanchey bazi start on account of #earthquake victims  http://t.co/MgTkaQrq5l',
#   'POS': [[('Khanchey', 'NNP'),
#     ('bazi', 'VBD'),
#     ('start', 'VB'),
#     ('on', 'IN'),
#     ('account', 'NN'),
#     ('of', 'IN'),
#     ('#', '#'),
#     ('earthquake', 'NN'),
#     ('victims', 'NNS'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/MgTkaQrq5l', 'NN')]]},
#  {'TweetID': '382813742683398144',
#   'Text': '1000+ died and countless injured,many homeless and living without any relief service after earthquake in #Balochistan http://t.co/E7sxwXwUJU',
#   'POS': [[('1000+', 'CD'),
#     ('died', 'VBD'),
#     ('and', 'CC'),
#     ('countless', 'NN'),
#     ('injured', 'VBD'),
#     (',', ','),
#     ('many', 'JJ'),
#     ('homeless', 'NN'),
#     ('and', 'CC'),
#     ('living', 'NN'),
#     ('without', 'IN'),
#     ('any', 'DT'),
#     ('relief', 'NN'),
#     ('service', 'NN'),
#     ('after', 'IN'),
#     ('earthquake', 'NN'),
#     ('in', 'IN'),
#     ('#', '#'),
#     ('Balochistan', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/E7sxwXwUJU', 'NN')]]},
#  {'TweetID': '382813761330888704',
#   'Text': 'Small island after earthquake in Pakistan http://t.co/ueRxtmpdZ4 #Pakistan #Gwadar #Balochistan #Earthquake #India via @Ma_knows_all00',
#   'POS': [[('Small', 'NNP'),
#     ('island', 'NN'),
#     ('after', 'IN'),
#     ('earthquake', 'NN'),
#     ('in', 'IN'),
#     ('Pakistan', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/ueRxtmpdZ4', 'JJ'),
#     ('#', '#'),
#     ('Pakistan', 'NNP'),
#     ('#', '#'),
#     ('Gwadar', 'NNP'),
#     ('#', '#'),
#     ('Balochistan', 'NNP'),
#     ('#', '#'),
#     ('Earthquake', 'NNP'),
#     ('#', '#'),
#     ('India', 'NNP'),
#     ('via', 'IN'),
#     ('@', 'NNP'),
#     ('Ma_knows_all00', 'NNP')]]},
#  {'TweetID': '382813775604105216',
#   'Text': 'Death toll in #Balochistan #earthquake mounts to 328 with 285 killed in #Awaran alone ~@PTVNewsOfficial #Pakistan',
#   'POS': [[('Death', 'NNP'),
#     ('toll', 'NN'),
#     ('in', 'IN'),
#     ('#', '#'),
#     ('Balochistan', 'NNP'),
#     ('#', '#'),
#     ('earthquake', 'NN'),
#     ('mounts', 'NNS'),
#     ('to', 'TO'),
#     ('328', 'CD'),
#     ('with', 'IN'),
#     ('285', 'CD'),
#     ('killed', 'VBN'),
#     ('in', 'IN'),
#     ('#', '#'),
#     ('Awaran', 'NNP'),
#     ('alone', 'RB'),
#     ('~', 'VBZ'),
#     ('@', 'JJ'),
#     ('PTVNewsOfficial', 'NNP'),
#     ('#', '#'),
#     ('Pakistan', 'NNP')]]},
#  {'TweetID': '382813776304541697',
#   'Text': 'RT @Twittistaan: NASA has released images of the new island formed after an earthquake in #Pakistan http://t.co/X3zSNm0Ma8 via @Independent',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('Twittistaan', 'NNP'),
#     (':', ':'),
#     ('NASA', 'NNP'),
#     ('has', 'VBZ'),
#     ('released', 'VBN'),
#     ('images', 'NNS'),
#     ('of', 'IN'),
#     ('the', 'DT'),
#     ('new', 'JJ'),
#     ('island', 'NN'),
#     ('formed', 'VBN'),
#     ('after', 'IN'),
#     ('an', 'DT'),
#     ('earthquake', 'NN'),
#     ('in', 'IN'),
#     ('#', '#'),
#     ('Pakistan', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/X3zSNm0Ma8', 'JJ'),
#     ('via', 'IN'),
#     ('@', 'JJ'),
#     ('Independent', 'NNP')]]},
#  {'TweetID': '382813788832940033',
#   'Text': "Balochistan #EarthQuake: Awaran's 95% houses are damaged - 1000+ deaths - Countless Injuries - No Medicines - No Relief. #Pakistan",
#   'POS': [[('Balochistan', 'NNP'),
#     ('#', '#'),
#     ('EarthQuake', 'NNP'),
#     (':', ':'),
#     ('Awaran', 'NNP'),
#     ("'s", 'POS'),
#     ('95', 'CD'),
#     ('%', 'NN'),
#     ('houses', 'NNS'),
#     ('are', 'VBP'),
#     ('damaged', 'VBN'),
#     ('-', ':'),
#     ('1000+', 'CD'),
#     ('deaths', 'NNS'),
#     ('-', ':'),
#     ('Countless', 'NNP'),
#     ('Injuries', 'NNP'),
#     ('-', ':'),
#     ('No', 'DT'),
#     ('Medicines', 'NNP'),
#     ('-', ':'),
#     ('No', 'DT'),
#     ('Relief', 'NNP'),
#     ('.', '.')],
#    [('#', '#'), ('Pakistan', 'NNP')]]},
#  {'TweetID': '382813812040409089',
#   'Text': 'RT @BalochTawar: Breaking News #EarthQuake of 5.5 Magnitude on ractel scale hit #Panjgur and #Awaran',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('BalochTawar', 'NNP'),
#     (':', ':'),
#     ('Breaking', 'NNP'),
#     ('News', 'NNP'),
#     ('#', '#'),
#     ('EarthQuake', 'NNP'),
#     ('of', 'IN'),
#     ('5.5', 'CD'),
#     ('Magnitude', 'NNP'),
#     ('on', 'IN'),
#     ('ractel', 'NN'),
#     ('scale', 'NN'),
#     ('hit', 'VBD'),
#     ('#', '#'),
#     ('Panjgur', 'NNP'),
#     ('and', 'CC'),
#     ('#', '#'),
#     ('Awaran', 'NNP')]]},
#  {'TweetID': '382813829719019521',
#   'Text': 'RT @WriterRod: Peru: State of emergency for areas affected by earthquake  http://t.co/ve1xJXEHjT via @PeruthisWeek #Peru #earthquake #terreâ€¦',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('WriterRod', 'NNP'),
#     (':', ':'),
#     ('Peru', 'NN'),
#     (':', ':'),
#     ('State', 'NN'),
#     ('of', 'IN'),
#     ('emergency', 'NN'),
#     ('for', 'IN'),
#     ('areas', 'NNS'),
#     ('affected', 'VBN'),
#     ('by', 'IN'),
#     ('earthquake', 'NN'),
#     ('http', 'NNS'),
#     (':', ':'),
#     ('//t.co/ve1xJXEHjT', 'NN'),
#     ('via', 'IN'),
#     ('@', 'NNP'),
#     ('PeruthisWeek', 'NNP'),
#     ('#', '#'),
#     ('Peru', 'NNP'),
#     ('#', '#'),
#     ('earthquake', 'NN'),
#     ('#', '#'),
#     ('terreâ€¦', 'NN')]]},
#  {'TweetID': '382813848006180864',
#   'Text': "RT @john_freiman: I was rocked by a M6.7 earthquake 81km NE of L'Esperance Rock, New Zealand!!! #earthquake #Quake_Watch_by_Ninja_Software",
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('john_freiman', 'NN'),
#     (':', ':'),
#     ('I', 'PRP'),
#     ('was', 'VBD'),
#     ('rocked', 'VBN'),
#     ('by', 'IN'),
#     ('a', 'DT'),
#     ('M6.7', 'NNP'),
#     ('earthquake', 'NN'),
#     ('81km', 'CD'),
#     ('NE', 'NNP'),
#     ('of', 'IN'),
#     ("L'Esperance", 'NNP'),
#     ('Rock', 'NNP'),
#     (',', ','),
#     ('New', 'NNP'),
#     ('Zealand', 'NNP'),
#     ('!', '.'),
#     ('!', '.'),
#     ('!', '.')],
#    [('#', '#'),
#     ('earthquake', 'NN'),
#     ('#', '#'),
#     ('Quake_Watch_by_Ninja_Software', 'NNP')]]},
#  {'TweetID': '382813873113284608',
#   'Text': '(News) The villages that were http://t.co/IPzABit3hZ #Earthquake #Pakistan',
#   'POS': [[('(', '('),
#     ('News', 'NNP'),
#     (')', ')'),
#     ('The', 'DT'),
#     ('villages', 'NNS'),
#     ('that', 'WDT'),
#     ('were', 'VBD'),
#     ('http', 'NNS'),
#     (':', ':'),
#     ('//t.co/IPzABit3hZ', 'NN'),
#     ('#', '#'),
#     ('Earthquake', 'NNP'),
#     ('#', '#'),
#     ('Pakistan', 'NNP')]]},
#  {'TweetID': '382813873679896576',
#   'Text': '(News) #Balochistan earthquake: Life among the ruins in #Gajjar http://t.co/1MJszlZrAb #Pakistan',
#   'POS': [[('(', '('),
#     ('News', 'NNP'),
#     (')', ')'),
#     ('#', '#'),
#     ('Balochistan', 'NNP'),
#     ('earthquake', 'NN'),
#     (':', ':'),
#     ('Life', 'NN'),
#     ('among', 'IN'),
#     ('the', 'DT'),
#     ('ruins', 'NNS'),
#     ('in', 'IN'),
#     ('#', '#'),
#     ('Gajjar', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/1MJszlZrAb', 'JJ'),
#     ('#', '#'),
#     ('Pakistan', 'NNP')]]},
#  {'TweetID': '382813914796290048',
#   'Text': 'Alert  U.S. Virgin Islands #Earthquake #Quake',
#   'POS': [[('Alert', 'NNP'),
#     ('U.S.', 'NNP'),
#     ('Virgin', 'NNP'),
#     ('Islands', 'NNP'),
#     ('#', '#'),
#     ('Earthquake', 'NNP'),
#     ('#', '#'),
#     ('Quake', 'NN')]]},
#  {'TweetID': '382813924208308224',
#   'Text': 'New #Earthquake Magnitude 2.2, Monday, September 30 2013 at 4:20:01 am (NZDT), 10 km east of Seddon: Public ID... http://t.co/d2TiBPftzL',
#   'POS': [[('New', 'NNP'),
#     ('#', '#'),
#     ('Earthquake', 'NNP'),
#     ('Magnitude', 'NNP'),
#     ('2.2', 'CD'),
#     (',', ','),
#     ('Monday', 'NNP'),
#     (',', ','),
#     ('September', 'NNP'),
#     ('30', 'CD'),
#     ('2013', 'CD'),
#     ('at', 'IN'),
#     ('4:20:01', 'CD'),
#     ('am', 'VBP'),
#     ('(', '('),
#     ('NZDT', 'NNP'),
#     (')', ')'),
#     (',', ','),
#     ('10', 'CD'),
#     ('km', 'NN'),
#     ('east', 'NN'),
#     ('of', 'IN'),
#     ('Seddon', 'NNP'),
#     (':', ':'),
#     ('Public', 'JJ'),
#     ('ID', 'NNP'),
#     ('...', ':'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/d2TiBPftzL', 'NN')]]},
#  {'TweetID': '382813932437917696',
#   'Text': 'Watching Pakistan #earthquake News! Shocked 2 c..ppl.they still waiting f any helps 2 save Life! WaheGuru!',
#   'POS': [[('Watching', 'VBG'),
#     ('Pakistan', 'NNP'),
#     ('#', '#'),
#     ('earthquake', 'NN'),
#     ('News', 'NN'),
#     ('!', '.')],
#    [('Shocked', 'JJ'),
#     ('2', 'CD'),
#     ('c..ppl.they', 'NN'),
#     ('still', 'RB'),
#     ('waiting', 'VBG'),
#     ('f', 'JJ'),
#     ('any', 'DT'),
#     ('helps', 'VBZ'),
#     ('2', 'CD'),
#     ('save', 'JJ'),
#     ('Life', 'NN'),
#     ('!', '.')],
#    [('WaheGuru', 'NN'), ('!', '.')]]},
#  {'TweetID': '382813945913831424',
#   'Text': 'RT @FoxNews: New massive earthquake rocks southwest #Pakistan http://t.co/QhOvQcq0jz',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('FoxNews', 'NNP'),
#     (':', ':'),
#     ('New', 'NNP'),
#     ('massive', 'JJ'),
#     ('earthquake', 'NN'),
#     ('rocks', 'NNS'),
#     ('southwest', 'VBP'),
#     ('#', '#'),
#     ('Pakistan', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/QhOvQcq0jz', 'NN')]]},
#  {'TweetID': '382813996354510848',
#   'Text': '#earthquake: M 2.3, Southern California http://t.co/P7YGfPBbQE',
#   'POS': [[('#', '#'),
#     ('earthquake', 'NN'),
#     (':', ':'),
#     ('M', 'NNP'),
#     ('2.3', 'CD'),
#     (',', ','),
#     ('Southern', 'NNP'),
#     ('California', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/P7YGfPBbQE', 'NN')]]},
#  {'TweetID': '382814017099558912',
#   'Text': '#earthquake M1.3: Southern California http://t.co/2vDndErHj1',
#   'POS': [[('#', '#'),
#     ('earthquake', 'NN'),
#     ('M1.3', 'NNS'),
#     (':', ':'),
#     ('Southern', 'NNP'),
#     ('California', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/2vDndErHj1', 'NN')]]},
#  {'TweetID': '382814060326043648',
#   'Text': "RT @janbaloch45: Don't Forget your #Awaran #Mashkay Brothers &amp; Sisters, You can donate blood for quake victims: Call: 03203202986  #Balochiâ€¦",
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('janbaloch45', 'NN'),
#     (':', ':'),
#     ('Do', 'VBP'),
#     ("n't", 'RB'),
#     ('Forget', 'VB'),
#     ('your', 'PRP$'),
#     ('#', '#'),
#     ('Awaran', 'NNP'),
#     ('#', '#'),
#     ('Mashkay', 'NNP'),
#     ('Brothers', 'NNPS'),
#     ('&', 'CC'),
#     ('amp', 'NN'),
#     (';', ':'),
#     ('Sisters', 'NNP'),
#     (',', ','),
#     ('You', 'PRP'),
#     ('can', 'MD'),
#     ('donate', 'VB'),
#     ('blood', 'NN'),
#     ('for', 'IN'),
#     ('quake', 'NN'),
#     ('victims', 'NNS'),
#     (':', ':'),
#     ('Call', 'NN'),
#     (':', ':'),
#     ('03203202986', 'CD'),
#     ('#', '#'),
#     ('Balochiâ€¦', 'NNP')]]},
#  {'TweetID': '382814060385161216',
#   'Text': 'RT @LBCI_News_EN: New major #earthquake rocks southwest #Pakistan | http://t.co/KR63qvgSRM |',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('LBCI_News_EN', 'NNP'),
#     (':', ':'),
#     ('New', 'NNP'),
#     ('major', 'JJ'),
#     ('#', '#'),
#     ('earthquake', 'NN'),
#     ('rocks', 'NNS'),
#     ('southwest', 'VBP'),
#     ('#', '#'),
#     ('Pakistan', 'NNP'),
#     ('|', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/KR63qvgSRM', 'NN'),
#     ('|', 'NN')]]},
#  {'TweetID': '382814062196703232',
#   'Text': 'RT @MrTippler: If Peace has killed people and destroyed lives for decades...how is it better than a War which might provide a resolution? #â€¦',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('MrTippler', 'NNP'),
#     (':', ':'),
#     ('If', 'IN'),
#     ('Peace', 'NNP'),
#     ('has', 'VBZ'),
#     ('killed', 'VBN'),
#     ('people', 'NNS'),
#     ('and', 'CC'),
#     ('destroyed', 'JJ'),
#     ('lives', 'NNS'),
#     ('for', 'IN'),
#     ('decades', 'NNS'),
#     ('...', ':'),
#     ('how', 'WRB'),
#     ('is', 'VBZ'),
#     ('it', 'PRP'),
#     ('better', 'JJR'),
#     ('than', 'IN'),
#     ('a', 'DT'),
#     ('War', 'NNP'),
#     ('which', 'WDT'),
#     ('might', 'MD'),
#     ('provide', 'VB'),
#     ('a', 'DT'),
#     ('resolution', 'NN'),
#     ('?', '.')],
#    [('#', '#'), ('â€¦', 'NN')]]},
#  {'TweetID': '382814062704226304',
#   'Text': 'UK PM left everything when just one soldier died. Here a 1000 are feared dead and our PM is no where to be seen! #Balochistan #earthquake',
#   'POS': [[('UK', 'NNP'),
#     ('PM', 'NNP'),
#     ('left', 'VBD'),
#     ('everything', 'NN'),
#     ('when', 'WRB'),
#     ('just', 'RB'),
#     ('one', 'CD'),
#     ('soldier', 'JJR'),
#     ('died', 'VBD'),
#     ('.', '.')],
#    [('Here', 'RB'),
#     ('a', 'DT'),
#     ('1000', 'CD'),
#     ('are', 'VBP'),
#     ('feared', 'VBN'),
#     ('dead', 'JJ'),
#     ('and', 'CC'),
#     ('our', 'PRP$'),
#     ('PM', 'NNP'),
#     ('is', 'VBZ'),
#     ('no', 'DT'),
#     ('where', 'WRB'),
#     ('to', 'TO'),
#     ('be', 'VB'),
#     ('seen', 'VBN'),
#     ('!', '.')],
#    [('#', '#'), ('Balochistan', 'NNP'), ('#', '#'), ('earthquake', 'NN')]]},
#  {'TweetID': '382814074104328192',
#   'Text': '5.0 #earthquake! Mon Sep 30 07:25:25 CDT 2013 near 142km NNW of #Kandrian, #PapuaNewGuinea http://t.co/yd9FKPWgGa',
#   'POS': [[('5.0', 'CD'), ('#', '#'), ('earthquake', 'NN'), ('!', '.')],
#    [('Mon', 'NNP'),
#     ('Sep', 'NNP'),
#     ('30', 'CD'),
#     ('07:25:25', 'CD'),
#     ('CDT', 'NN'),
#     ('2013', 'CD'),
#     ('near', 'IN'),
#     ('142km', 'CD'),
#     ('NNW', 'NNP'),
#     ('of', 'IN'),
#     ('#', '#'),
#     ('Kandrian', 'NNP'),
#     (',', ','),
#     ('#', '#'),
#     ('PapuaNewGuinea', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/yd9FKPWgGa', 'NN')]]},
#  {'TweetID': '382814074439868419',
#   'Text': '#currently #reading #word #wisdom #earthquake #faith #praying ðŸ™\x8fðŸ™\x8f http://t.co/deHuDeYqrj',
#   'POS': [[('#', '#'),
#     ('currently', 'RB'),
#     ('#', '#'),
#     ('reading', 'VBG'),
#     ('#', '#'),
#     ('word', 'NN'),
#     ('#', '#'),
#     ('wisdom', 'NN'),
#     ('#', '#'),
#     ('earthquake', 'NN'),
#     ('#', '#'),
#     ('faith', 'NN'),
#     ('#', '#'),
#     ('praying', 'VBG'),
#     ('ðŸ™\x8fðŸ™\x8f', 'JJ'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/deHuDeYqrj', 'NN')]]},
#  {'TweetID': '382814086519869441',
#   'Text': 'RT @diplo: Twerkbook pro #plurnt #earthquake http://t.co/5x5ya6wxF6',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('diplo', 'NN'),
#     (':', ':'),
#     ('Twerkbook', 'NNP'),
#     ('pro', 'FW'),
#     ('#', '#'),
#     ('plurnt', 'NN'),
#     ('#', '#'),
#     ('earthquake', 'NN'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/5x5ya6wxF6', 'NN')]]},
#  {'TweetID': '382814114860367872',
#   'Text': 'Earthquakes in #Pakistan timeline http://t.co/Y20lGxf9Pi Worst earthquake in 2005. 80,000 dead, 200,000 injured, 4 million ppl left homeless',
#   'POS': [[('Earthquakes', 'NNS'),
#     ('in', 'IN'),
#     ('#', '#'),
#     ('Pakistan', 'NNP'),
#     ('timeline', 'NN'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/Y20lGxf9Pi', 'NN'),
#     ('Worst', 'NNP'),
#     ('earthquake', 'NN'),
#     ('in', 'IN'),
#     ('2005', 'CD'),
#     ('.', '.')],
#    [('80,000', 'CD'),
#     ('dead', 'JJ'),
#     (',', ','),
#     ('200,000', 'CD'),
#     ('injured', 'JJ'),
#     (',', ','),
#     ('4', 'CD'),
#     ('million', 'CD'),
#     ('ppl', 'NN'),
#     ('left', 'VBD'),
#     ('homeless', 'NN')]]},
#  {'TweetID': '382814115276025856',
#   'Text': 'How can anyone dislike #SMAP? Those guys are awesome. #311 #earthquake',
#   'POS': [[('How', 'WRB'),
#     ('can', 'MD'),
#     ('anyone', 'NN'),
#     ('dislike', 'VB'),
#     ('#', '#'),
#     ('SMAP', 'NNP'),
#     ('?', '.')],
#    [('Those', 'DT'),
#     ('guys', 'NNS'),
#     ('are', 'VBP'),
#     ('awesome', 'JJ'),
#     ('.', '.')],
#    [('#', '#'), ('311', 'CD'), ('#', '#'), ('earthquake', 'NN')]]},
#  {'TweetID': '382814116127465472',
#   'Text': 'RT @ITs_AzaD: Please Help Awaran and Kech EarthQuake Victims. #Balochistan https://t.co/qzpCyT38va @hrw @UN_HRC @HRC @Refugees',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('ITs_AzaD', 'NNP'),
#     (':', ':'),
#     ('Please', 'NNP'),
#     ('Help', 'NNP'),
#     ('Awaran', 'NNP'),
#     ('and', 'CC'),
#     ('Kech', 'NNP'),
#     ('EarthQuake', 'NNP'),
#     ('Victims', 'NNP'),
#     ('.', '.')],
#    [('#', '#'),
#     ('Balochistan', 'NNP'),
#     ('https', 'NN'),
#     (':', ':'),
#     ('//t.co/qzpCyT38va', 'JJ'),
#     ('@', 'NNP'),
#     ('hrw', 'NN'),
#     ('@', 'NNP'),
#     ('UN_HRC', 'NNP'),
#     ('@', 'NNP'),
#     ('HRC', 'NNP'),
#     ('@', 'NNP'),
#     ('Refugees', 'NNP')]]},
#  {'TweetID': '382814118056431616',
#   'Text': 'RT @JuD_Cyberteam: #JUDReleif International Media Coverage in @BBCUrdu  #Earthquake http://t.co/wiV9lPdTZt',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('JuD_Cyberteam', 'NNP'),
#     (':', ':'),
#     ('#', '#'),
#     ('JUDReleif', 'NNP'),
#     ('International', 'NNP'),
#     ('Media', 'NNP'),
#     ('Coverage', 'NNP'),
#     ('in', 'IN'),
#     ('@', 'NNP'),
#     ('BBCUrdu', 'NNP'),
#     ('#', '#'),
#     ('Earthquake', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/wiV9lPdTZt', 'NN')]]},
#  {'TweetID': '382814125673693184',
#   'Text': '#Balochistan PDMA is doing what it can with the next to nothing resources it has.. help them out people.. Ask them what they need exactly',
#   'POS': [[('#', '#'),
#     ('Balochistan', 'NNP'),
#     ('PDMA', 'NNP'),
#     ('is', 'VBZ'),
#     ('doing', 'VBG'),
#     ('what', 'WP'),
#     ('it', 'PRP'),
#     ('can', 'MD'),
#     ('with', 'IN'),
#     ('the', 'DT'),
#     ('next', 'JJ'),
#     ('to', 'TO'),
#     ('nothing', 'NN'),
#     ('resources', 'NNS'),
#     ('it', 'PRP'),
#     ('has..', 'VBZ'),
#     ('help', 'VB'),
#     ('them', 'PRP'),
#     ('out', 'RP'),
#     ('people..', 'NN')],
#    [('Ask', 'VB'),
#     ('them', 'PRP'),
#     ('what', 'WP'),
#     ('they', 'PRP'),
#     ('need', 'VBP'),
#     ('exactly', 'RB')]]},
#  {'TweetID': '382814125899784192',
#   'Text': '2.4 magnitude #earthquake. 18km N of Middleton Island, Alaska.http://t.co/pZJnCOqquV',
#   'POS': [[('2.4', 'CD'),
#     ('magnitude', 'NN'),
#     ('#', '#'),
#     ('earthquake', 'NN'),
#     ('.', '.')],
#    [('18km', 'CD'),
#     ('N', 'NNP'),
#     ('of', 'IN'),
#     ('Middleton', 'NNP'),
#     ('Island', 'NNP'),
#     (',', ','),
#     ('Alaska.http', 'NNP'),
#     (':', ':'),
#     ('//t.co/pZJnCOqquV', 'NN')]]},
#  {'TweetID': '382814128102182912',
#   'Text': 'RT @AstroEnrico: 7.7 magnitude #quake in #Pakistan just created a new island https://t.co/GYyUNZCWl0',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('AstroEnrico', 'NNP'),
#     (':', ':'),
#     ('7.7', 'CD'),
#     ('magnitude', 'NN'),
#     ('#', '#'),
#     ('quake', 'NN'),
#     ('in', 'IN'),
#     ('#', '#'),
#     ('Pakistan', 'NNP'),
#     ('just', 'RB'),
#     ('created', 'VBD'),
#     ('a', 'DT'),
#     ('new', 'JJ'),
#     ('island', 'NN'),
#     ('https', 'NN'),
#     (':', ':'),
#     ('//t.co/GYyUNZCWl0', 'NN')]]},
#  {'TweetID': '382814132225191936',
#   'Text': 'RT @AsCorrespondent: Pakistanis struggle for food, shelter after quake  http://t.co/5PBQAdPaqQ #Pakistan',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('AsCorrespondent', 'NNP'),
#     (':', ':'),
#     ('Pakistanis', 'NNP'),
#     ('struggle', 'NN'),
#     ('for', 'IN'),
#     ('food', 'NN'),
#     (',', ','),
#     ('shelter', 'NN'),
#     ('after', 'IN'),
#     ('quake', 'NN'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/5PBQAdPaqQ', 'JJ'),
#     ('#', '#'),
#     ('Pakistan', 'NNP')]]},
#  {'TweetID': '382814134032531456',
#   'Text': 'RT @AnasMallick: More than 5 dozen #Earthquake victims, mostly women and children, shifted to #Karachi from #Awaran.',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('AnasMallick', 'NNP'),
#     (':', ':'),
#     ('More', 'JJR'),
#     ('than', 'IN'),
#     ('5', 'CD'),
#     ('dozen', 'NN'),
#     ('#', '#'),
#     ('Earthquake', 'NNP'),
#     ('victims', 'NNS'),
#     (',', ','),
#     ('mostly', 'RB'),
#     ('women', 'NNS'),
#     ('and', 'CC'),
#     ('children', 'NNS'),
#     (',', ','),
#     ('shifted', 'VBN'),
#     ('to', 'TO'),
#     ('#', '#'),
#     ('Karachi', 'NNP'),
#     ('from', 'IN'),
#     ('#', '#'),
#     ('Awaran', 'NNP'),
#     ('.', '.')]]},
#  {'TweetID': '382814136285274112',
#   'Text': 'RT @EarthAlerts: #earthquake: M 3.1 - South-America Chile [Atacama] Vallenar: Preliminary Earthquake Report:  Date/Time: 27.0... http://t.câ€¦',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('EarthAlerts', 'NNP'),
#     (':', ':'),
#     ('#', '#'),
#     ('earthquake', 'NN'),
#     (':', ':'),
#     ('M', 'NNP'),
#     ('3.1', 'CD'),
#     ('-', ':'),
#     ('South-America', 'JJ'),
#     ('Chile', 'NNP'),
#     ('[', 'NNP'),
#     ('Atacama', 'NNP'),
#     (']', 'NNP'),
#     ('Vallenar', 'NNP'),
#     (':', ':'),
#     ('Preliminary', 'JJ'),
#     ('Earthquake', 'NNP'),
#     ('Report', 'NNP'),
#     (':', ':'),
#     ('Date/Time', 'NN'),
#     (':', ':'),
#     ('27.0', 'CD'),
#     ('...', ':'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.câ€¦', 'NN')]]},
#  {'TweetID': '382814138235236352',
#   'Text': 'RT @seismicupdate: #USGS M 3.0, 62km NNE of Road Town, British Virgin Islands http://t.co/kkWk0fvYR5 #earthquake',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('seismicupdate', 'NN'),
#     (':', ':'),
#     ('#', '#'),
#     ('USGS', 'NNP'),
#     ('M', 'NNP'),
#     ('3.0', 'CD'),
#     (',', ','),
#     ('62km', 'CD'),
#     ('NNE', 'NNP'),
#     ('of', 'IN'),
#     ('Road', 'NNP'),
#     ('Town', 'NNP'),
#     (',', ','),
#     ('British', 'NNP'),
#     ('Virgin', 'NNP'),
#     ('Islands', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/kkWk0fvYR5', 'JJ'),
#     ('#', '#'),
#     ('earthquake', 'NN')]]},
#  {'TweetID': '382814139623931904',
#   'Text': 'RT @everyEarthquake: USGS reports a M2.8 #earthquake 5km ENE of Badger, Alaska on 9/28/13 @ 22:26:21 UTC http://t.co/EBf5HJIMrz #quake',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('everyEarthquake', 'NN'),
#     (':', ':'),
#     ('USGS', 'NNP'),
#     ('reports', 'VBZ'),
#     ('a', 'DT'),
#     ('M2.8', 'NNP'),
#     ('#', '#'),
#     ('earthquake', 'NN'),
#     ('5km', 'CD'),
#     ('ENE', 'NNP'),
#     ('of', 'IN'),
#     ('Badger', 'NNP'),
#     (',', ','),
#     ('Alaska', 'NNP'),
#     ('on', 'IN'),
#     ('9/28/13', 'CD'),
#     ('@', 'JJ'),
#     ('22:26:21', 'CD'),
#     ('UTC', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/EBf5HJIMrz', 'JJ'),
#     ('#', '#'),
#     ('quake', 'NN')]]},
#  {'TweetID': '382814141620043776',
#   'Text': '2.5 magnitude #earthquake. 9 mi from Hollister, CA, United States.http://t.co/fVg6dLjmYb',
#   'POS': [[('2.5', 'CD'),
#     ('magnitude', 'NN'),
#     ('#', '#'),
#     ('earthquake', 'NN'),
#     ('.', '.')],
#    [('9', 'CD'),
#     ('mi', 'NN'),
#     ('from', 'IN'),
#     ('Hollister', 'NNP'),
#     (',', ','),
#     ('CA', 'NNP'),
#     (',', ','),
#     ('United', 'NNP'),
#     ('States.http', 'NNP'),
#     (':', ':'),
#     ('//t.co/fVg6dLjmYb', 'NN')]]},
#  {'TweetID': '382814144824479746',
#   'Text': '#earthquake M 6.7, Kermadec Islands, New Zealand http://t.co/ueylGfr3NX',
#   'POS': [[('#', '#'),
#     ('earthquake', 'NN'),
#     ('M', 'NNP'),
#     ('6.7', 'CD'),
#     (',', ','),
#     ('Kermadec', 'NNP'),
#     ('Islands', 'NNP'),
#     (',', ','),
#     ('New', 'NNP'),
#     ('Zealand', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/ueylGfr3NX', 'NN')]]},
#  {'TweetID': '382814146620059648',
#   'Text': '#Pakistan PM Nawaz Sharif said â€œIslam is a religion of peace, compassion and brotherhood.â€\x9d',
#   'POS': [[('#', '#'),
#     ('Pakistan', 'NNP'),
#     ('PM', 'NNP'),
#     ('Nawaz', 'NNP'),
#     ('Sharif', 'NNP'),
#     ('said', 'VBD'),
#     ('â€œIslam', 'NNP'),
#     ('is', 'VBZ'),
#     ('a', 'DT'),
#     ('religion', 'NN'),
#     ('of', 'IN'),
#     ('peace', 'NN'),
#     (',', ','),
#     ('compassion', 'NN'),
#     ('and', 'CC'),
#     ('brotherhood.â€\x9d', 'NN')]]},
#  {'TweetID': '382814146691346432',
#   'Text': '#ThanksMQM for helping people of #Pakistan in their bad &amp;amp;amp;amp;amp; good times via #KKF',
#   'POS': [[('#', '#'),
#     ('ThanksMQM', 'NNP'),
#     ('for', 'IN'),
#     ('helping', 'VBG'),
#     ('people', 'NNS'),
#     ('of', 'IN'),
#     ('#', '#'),
#     ('Pakistan', 'NNP'),
#     ('in', 'IN'),
#     ('their', 'PRP$'),
#     ('bad', 'JJ'),
#     ('&', 'CC'),
#     ('amp', 'NN'),
#     (';', ':'),
#     ('amp', 'CC'),
#     (';', ':'),
#     ('amp', 'NN'),
#     (';', ':'),
#     ('amp', 'CC'),
#     (';', ':'),
#     ('amp', 'NN'),
#     (';', ':'),
#     ('good', 'JJ'),
#     ('times', 'NNS'),
#     ('via', 'IN'),
#     ('#', '#'),
#     ('KKF', 'NNP')]]},
#  {'TweetID': '382814148851023872',
#   'Text': 'RT @AsimBajwaISPR: #Earthquake: Appreciate the spirit of this young donor- F-9 Park Collection Point, Isd. http://t.co/x7G3SAfjNZ',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('AsimBajwaISPR', 'NNP'),
#     (':', ':'),
#     ('#', '#'),
#     ('Earthquake', 'NN'),
#     (':', ':'),
#     ('Appreciate', 'VB'),
#     ('the', 'DT'),
#     ('spirit', 'NN'),
#     ('of', 'IN'),
#     ('this', 'DT'),
#     ('young', 'JJ'),
#     ('donor-', 'JJ'),
#     ('F-9', 'NNP'),
#     ('Park', 'NNP'),
#     ('Collection', 'NNP'),
#     ('Point', 'NNP'),
#     (',', ','),
#     ('Isd', 'NNP'),
#     ('.', '.')],
#    [('http', 'NN'), (':', ':'), ('//t.co/x7G3SAfjNZ', 'NN')]]},
#  {'TweetID': '382814149165973504',
#   'Text': '#earthquake M7.0 NEAR THE COAST OF SOUTHERN PERU 45.8km 2013/09/26 01:42:43 JST[UTC+9 (G)http://t.co/Si755wz4lQ (USGS)http://t.co/6m5EfUHRAu',
#   'POS': [[('#', '#'),
#     ('earthquake', 'NN'),
#     ('M7.0', 'NNP'),
#     ('NEAR', 'NNP'),
#     ('THE', 'NNP'),
#     ('COAST', 'NNP'),
#     ('OF', 'NNP'),
#     ('SOUTHERN', 'NNP'),
#     ('PERU', 'NNP'),
#     ('45.8km', 'CD'),
#     ('2013/09/26', 'CD'),
#     ('01:42:43', 'CD'),
#     ('JST', 'NNP'),
#     ('[', 'NNP'),
#     ('UTC+9', 'NNP'),
#     ('(', '('),
#     ('G', 'NNP'),
#     (')', ')'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/Si755wz4lQ', 'NN'),
#     ('(', '('),
#     ('USGS', 'NNP'),
#     (')', ')'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/6m5EfUHRAu', 'NN')]]},
#  {'TweetID': '382814152969838592',
#   'Text': '@PatriciaLMalik The 7.8 magnitude #earthquake in #Pakistan creates island off the coast of Balochistan http://t.co/O6Y6ilAu9o #jetlagged',
#   'POS': [[('@', 'NN'),
#     ('PatriciaLMalik', 'NNP'),
#     ('The', 'DT'),
#     ('7.8', 'CD'),
#     ('magnitude', 'NN'),
#     ('#', '#'),
#     ('earthquake', 'NN'),
#     ('in', 'IN'),
#     ('#', '#'),
#     ('Pakistan', 'NNP'),
#     ('creates', 'NNS'),
#     ('island', 'VBP'),
#     ('off', 'IN'),
#     ('the', 'DT'),
#     ('coast', 'NN'),
#     ('of', 'IN'),
#     ('Balochistan', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/O6Y6ilAu9o', 'JJ'),
#     ('#', '#'),
#     ('jetlagged', 'VBD')]]},
#  {'TweetID': '382814154165612544',
#   'Text': 'News: #KKF Have Dispatched Three Trucks Loaded with Relief Goods for #Baluchistan #Earthquake Victims #ReliefByKKF http://t.co/2j3BPtc9FT',
#   'POS': [[('News', 'NNS'),
#     (':', ':'),
#     ('#', '#'),
#     ('KKF', 'NNP'),
#     ('Have', 'NNP'),
#     ('Dispatched', 'NNP'),
#     ('Three', 'NNP'),
#     ('Trucks', 'NNP'),
#     ('Loaded', 'VBD'),
#     ('with', 'IN'),
#     ('Relief', 'NNP'),
#     ('Goods', 'NNP'),
#     ('for', 'IN'),
#     ('#', '#'),
#     ('Baluchistan', 'NNP'),
#     ('#', '#'),
#     ('Earthquake', 'NNP'),
#     ('Victims', 'NNP'),
#     ('#', '#'),
#     ('ReliefByKKF', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/2j3BPtc9FT', 'NN')]]},
#  {'TweetID': '382814156857950208',
#   'Text': '#Web:  Powerful 6.1-magnitude #earthquake strikes #Mexico http://t.co/hHDyLmTqMa',
#   'POS': [[('#', '#'),
#     ('Web', 'NNP'),
#     (':', ':'),
#     ('Powerful', 'JJ'),
#     ('6.1-magnitude', 'JJ'),
#     ('#', '#'),
#     ('earthquake', 'NN'),
#     ('strikes', 'NNS'),
#     ('#', '#'),
#     ('Mexico', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/hHDyLmTqMa', 'NN')]]},
#  {'TweetID': '382814157248409600',
#   'Text': '#WhereIsNationalCounterTerrorismPolicy Nawaz shud know there is country call Pakistan. He is incharge of it #earthquake #terrorism #flood',
#   'POS': [[('#', '#'),
#     ('WhereIsNationalCounterTerrorismPolicy', 'NNP'),
#     ('Nawaz', 'NNP'),
#     ('shud', 'NN'),
#     ('know', 'VBP'),
#     ('there', 'EX'),
#     ('is', 'VBZ'),
#     ('country', 'NN'),
#     ('call', 'NN'),
#     ('Pakistan', 'NNP'),
#     ('.', '.')],
#    [('He', 'PRP'),
#     ('is', 'VBZ'),
#     ('incharge', 'NN'),
#     ('of', 'IN'),
#     ('it', 'PRP'),
#     ('#', '#'),
#     ('earthquake', 'NN'),
#     ('#', '#'),
#     ('terrorism', 'NN'),
#     ('#', '#'),
#     ('flood', 'NN')]]},
#  {'TweetID': '382814158682877952',
#   'Text': '1.6 magnitude #earthquake. 5 km from Yucca Valley, CA, United States.http://t.co/zzzmE4uZ67',
#   'POS': [[('1.6', 'CD'),
#     ('magnitude', 'NN'),
#     ('#', '#'),
#     ('earthquake', 'NN'),
#     ('.', '.')],
#    [('5', 'CD'),
#     ('km', 'NN'),
#     ('from', 'IN'),
#     ('Yucca', 'NNP'),
#     ('Valley', 'NNP'),
#     (',', ','),
#     ('CA', 'NNP'),
#     (',', ','),
#     ('United', 'NNP'),
#     ('States.http', 'NNP'),
#     (':', ':'),
#     ('//t.co/zzzmE4uZ67', 'NN')]]},
#  {'TweetID': '382814164319993856',
#   'Text': '#earthquake: M 1.0, Northern California http://t.co/uWqg8RYyIV',
#   'POS': [[('#', '#'),
#     ('earthquake', 'NN'),
#     (':', ':'),
#     ('M', 'NNP'),
#     ('1.0', 'CD'),
#     (',', ','),
#     ('Northern', 'NNP'),
#     ('California', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/uWqg8RYyIV', 'NN')]]},
#  {'TweetID': '382814178768990208',
#   'Text': 'Some sources said that 1200 rape cases have been registered in #Pakistan in last 6 months. :-( Nation needs some lectures on ethics.',
#   'POS': [[('Some', 'DT'),
#     ('sources', 'NNS'),
#     ('said', 'VBD'),
#     ('that', 'IN'),
#     ('1200', 'CD'),
#     ('rape', 'NN'),
#     ('cases', 'NNS'),
#     ('have', 'VBP'),
#     ('been', 'VBN'),
#     ('registered', 'VBN'),
#     ('in', 'IN'),
#     ('#', '#'),
#     ('Pakistan', 'NNP'),
#     ('in', 'IN'),
#     ('last', 'JJ'),
#     ('6', 'CD'),
#     ('months', 'NNS'),
#     ('.', '.')],
#    [(':', ':'),
#     ('-', ':'),
#     ('(', '('),
#     ('Nation', 'NNP'),
#     ('needs', 'VBZ'),
#     ('some', 'DT'),
#     ('lectures', 'NNS'),
#     ('on', 'IN'),
#     ('ethics', 'NNS'),
#     ('.', '.')]]},
#  {'TweetID': '382814179624628224',
#   'Text': 'RT @UWT_UK: Tent villages have been set up in in Muzaffargar, #Pakistan to help families affected by flooding. http://t.co/eqg3uuV47w',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('UWT_UK', 'NNP'),
#     (':', ':'),
#     ('Tent', 'NN'),
#     ('villages', 'NNS'),
#     ('have', 'VBP'),
#     ('been', 'VBN'),
#     ('set', 'VBN'),
#     ('up', 'RP'),
#     ('in', 'IN'),
#     ('in', 'IN'),
#     ('Muzaffargar', 'NNP'),
#     (',', ','),
#     ('#', '#'),
#     ('Pakistan', 'NNP'),
#     ('to', 'TO'),
#     ('help', 'VB'),
#     ('families', 'NNS'),
#     ('affected', 'VBN'),
#     ('by', 'IN'),
#     ('flooding', 'VBG'),
#     ('.', '.')],
#    [('http', 'NN'), (':', ':'), ('//t.co/eqg3uuV47w', 'NN')]]},
#  {'TweetID': '382814190421168128',
#   'Text': "Death toll reaches 329. They have run out of 'kafan'. Ya Allah rehem!  #Earthquake #Awaran",
#   'POS': [[('Death', 'NNP'),
#     ('toll', 'NN'),
#     ('reaches', 'VBZ'),
#     ('329', 'CD'),
#     ('.', '.')],
#    [('They', 'PRP'),
#     ('have', 'VBP'),
#     ('run', 'VBN'),
#     ('out', 'IN'),
#     ('of', 'IN'),
#     ("'kafan", 'NN'),
#     ("'", 'POS'),
#     ('.', '.')],
#    [('Ya', 'NNP'), ('Allah', 'NNP'), ('rehem', 'NN'), ('!', '.')],
#    [('#', '#'), ('Earthquake', 'NNP'), ('#', '#'), ('Awaran', 'NNP')]]},
#  {'TweetID': '382814241843343361',
# ...
#   'POS': [[('[', 'JJ'),
#     ('Epicenter', 'NNP'),
#     (']', 'NNP'),
#     ('Miyagi', 'NNP'),
#     ('Coast', 'NNP'),
#     ('[', 'NNP'),
#     ('Max', 'NNP'),
#     ('Shindo', 'NNP'),
#     (']', 'VBZ'),
#     ('1', 'CD'),
#     ('(', '('),
#     ('2013-9-27', 'JJ'),
#     (',', ','),
#     ('7:44', 'CD'),
#     (')', ')'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/fUXRZPxRk2', 'JJ'),
#     ('#', '#'),
#     ('earthquake', 'NN'),
#     ('#', '#'),
#     ('jpquake', 'NN')]]},
#  {'TweetID': '382827072655482880',
#   'Text': "@essel1 Attention was on #KPK, #Pakistan when unfortunate blast in #Church killed many. Why no focus on today's or on yesterday's bus blast?",
#   'POS': [[('@', 'NN'),
#     ('essel1', 'DT'),
#     ('Attention', 'NNP'),
#     ('was', 'VBD'),
#     ('on', 'IN'),
#     ('#', '#'),
#     ('KPK', 'NNP'),
#     (',', ','),
#     ('#', '#'),
#     ('Pakistan', 'NNP'),
#     ('when', 'WRB'),
#     ('unfortunate', 'JJ'),
#     ('blast', 'NN'),
#     ('in', 'IN'),
#     ('#', '#'),
#     ('Church', 'NNP'),
#     ('killed', 'VBD'),
#     ('many', 'JJ'),
#     ('.', '.')],
#    [('Why', 'WRB'),
#     ('no', 'DT'),
#     ('focus', 'NN'),
#     ('on', 'IN'),
#     ('today', 'NN'),
#     ("'s", 'POS'),
#     ('or', 'CC'),
#     ('on', 'IN'),
#     ('yesterday', 'NN'),
#     ("'s", 'POS'),
#     ('bus', 'NN'),
#     ('blast', 'NN'),
#     ('?', '.')]]},
#  {'TweetID': '382827072747753472',
#   'Text': 'RT @robertspeta: Island off of Gwadar formed after todays earthquake in #Pakistan http://t.co/SIdP7CGwGi',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('robertspeta', 'NN'),
#     (':', ':'),
#     ('Island', 'NNP'),
#     ('off', 'IN'),
#     ('of', 'IN'),
#     ('Gwadar', 'NNP'),
#     ('formed', 'VBD'),
#     ('after', 'IN'),
#     ('todays', 'NNS'),
#     ('earthquake', 'NN'),
#     ('in', 'IN'),
#     ('#', '#'),
#     ('Pakistan', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/SIdP7CGwGi', 'NN')]]},
#  {'TweetID': '382827078770782208',
#   'Text': 'BREAKING: Earthquake Tremors felt in Thatta, no reports of loss of life or any type of property in this earthquake. #Karachi #Pakistan',
#   'POS': [[('BREAKING', 'NN'),
#     (':', ':'),
#     ('Earthquake', 'NN'),
#     ('Tremors', 'NNS'),
#     ('felt', 'VBD'),
#     ('in', 'IN'),
#     ('Thatta', 'NNP'),
#     (',', ','),
#     ('no', 'DT'),
#     ('reports', 'NNS'),
#     ('of', 'IN'),
#     ('loss', 'NN'),
#     ('of', 'IN'),
#     ('life', 'NN'),
#     ('or', 'CC'),
#     ('any', 'DT'),
#     ('type', 'NN'),
#     ('of', 'IN'),
#     ('property', 'NN'),
#     ('in', 'IN'),
#     ('this', 'DT'),
#     ('earthquake', 'NN'),
#     ('.', '.')],
#    [('#', '#'), ('Karachi', 'NNP'), ('#', '#'), ('Pakistan', 'NNP')]]},
#  {'TweetID': '382827083023396865',
#   'Text': 'RT @BhaiChod: #Satellite images of the damages #Earthquake #Balochistan #Awaran http://t.co/NqiFgqVN1c and #Gajar http://t.co/JQ6hl8ftlt #Uâ€¦',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('BhaiChod', 'NNP'),
#     (':', ':'),
#     ('#', '#'),
#     ('Satellite', 'NNP'),
#     ('images', 'NNS'),
#     ('of', 'IN'),
#     ('the', 'DT'),
#     ('damages', 'NNS'),
#     ('#', '#'),
#     ('Earthquake', 'NNP'),
#     ('#', '#'),
#     ('Balochistan', 'NNP'),
#     ('#', '#'),
#     ('Awaran', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/NqiFgqVN1c', 'NN'),
#     ('and', 'CC'),
#     ('#', '#'),
#     ('Gajar', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/JQ6hl8ftlt', 'JJ'),
#     ('#', '#'),
#     ('Uâ€¦', 'NNP')]]},
#  {'TweetID': '382827096688848896',
#   'Text': 'RT @bbcworldservice: Number dead in #Pakistan #quake is 348 and rising + 513 injured + 2 army units helping in rescue, disaster operations â€¦',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('bbcworldservice', 'NN'),
#     (':', ':'),
#     ('Number', 'NNP'),
#     ('dead', 'VBP'),
#     ('in', 'IN'),
#     ('#', '#'),
#     ('Pakistan', 'NNP'),
#     ('#', '#'),
#     ('quake', 'NN'),
#     ('is', 'VBZ'),
#     ('348', 'CD'),
#     ('and', 'CC'),
#     ('rising', 'VBG'),
#     ('+', 'RB'),
#     ('513', 'CD'),
#     ('injured', 'JJ'),
#     ('+', 'RB'),
#     ('2', 'CD'),
#     ('army', 'JJ'),
#     ('units', 'NNS'),
#     ('helping', 'VBG'),
#     ('in', 'IN'),
#     ('rescue', 'NN'),
#     (',', ','),
#     ('disaster', 'NN'),
#     ('operations', 'NNS'),
#     ('â€¦', 'VBP')]]},
#  {'TweetID': '382827129991221249',
#   'Text': '#Sismo #Earthquake M 2.7, 5km S of Volcano, Hawaii http://t.co/L1o9GTtlCw',
#   'POS': [[('#', '#'),
#     ('Sismo', 'NNP'),
#     ('#', '#'),
#     ('Earthquake', 'NNP'),
#     ('M', 'NNP'),
#     ('2.7', 'CD'),
#     (',', ','),
#     ('5km', 'CD'),
#     ('S', 'NNP'),
#     ('of', 'IN'),
#     ('Volcano', 'NNP'),
#     (',', ','),
#     ('Hawaii', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/L1o9GTtlCw', 'NN')]]},
#  {'TweetID': '382827130796519424',
#   'Text': 'RT @bbclysedoucet: Another attack #Peshawar - more than 30 dead &amp; 80+ injured. Much anger &amp; anguish #Pakistan - 3rd attack in a week in thiâ€¦',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('bbclysedoucet', 'NN'),
#     (':', ':'),
#     ('Another', 'DT'),
#     ('attack', 'NN'),
#     ('#', '#'),
#     ('Peshawar', 'NNP'),
#     ('-', ':'),
#     ('more', 'JJR'),
#     ('than', 'IN'),
#     ('30', 'CD'),
#     ('dead', 'JJ'),
#     ('&', 'CC'),
#     ('amp', 'NN'),
#     (';', ':'),
#     ('80+', 'CD'),
#     ('injured', 'JJ'),
#     ('.', '.')],
#    [('Much', 'JJ'),
#     ('anger', 'NN'),
#     ('&', 'CC'),
#     ('amp', 'NN'),
#     (';', ':'),
#     ('anguish', 'JJ'),
#     ('#', '#'),
#     ('Pakistan', 'NNP'),
#     ('-', ':'),
#     ('3rd', 'CD'),
#     ('attack', 'NN'),
#     ('in', 'IN'),
#     ('a', 'DT'),
#     ('week', 'NN'),
#     ('in', 'IN'),
#     ('thiâ€¦', 'NN')]]},
#  {'TweetID': '382827131350171648',
#   'Text': 'RT @HumanityRoad: #Peru #Earthquake revised to 7.0M felt across 1,200 miles from Huacho, Peru to Iquique, Chile http://t.co/RnH0DK6IK5 #Terâ€¦',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('HumanityRoad', 'NNP'),
#     (':', ':'),
#     ('#', '#'),
#     ('Peru', 'NNP'),
#     ('#', '#'),
#     ('Earthquake', 'NNP'),
#     ('revised', 'VBD'),
#     ('to', 'TO'),
#     ('7.0M', 'CD'),
#     ('felt', 'NNS'),
#     ('across', 'IN'),
#     ('1,200', 'CD'),
#     ('miles', 'NNS'),
#     ('from', 'IN'),
#     ('Huacho', 'NNP'),
#     (',', ','),
#     ('Peru', 'NNP'),
#     ('to', 'TO'),
#     ('Iquique', 'NNP'),
#     (',', ','),
#     ('Chile', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/RnH0DK6IK5', 'JJ'),
#     ('#', '#'),
#     ('Terâ€¦', 'NNP')]]},
#  {'TweetID': '382827132029640705',
#   'Text': '#Earthquake M 3.1, northern Alaska http://t.co/o7qaVFic1C',
#   'POS': [[('#', '#'),
#     ('Earthquake', 'NNP'),
#     ('M', 'NNP'),
#     ('3.1', 'CD'),
#     (',', ','),
#     ('northern', 'JJ'),
#     ('Alaska', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/o7qaVFic1C', 'NN')]]},
#  {'TweetID': '382827132658782209',
#   'Text': 'RT @SS_Serene: #PrayForPakistan thoughts and prayers with the displaced and the families of those dead and injured. #Balochistan',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('SS_Serene', 'NNP'),
#     (':', ':'),
#     ('#', '#'),
#     ('PrayForPakistan', 'NNP'),
#     ('thoughts', 'NNS'),
#     ('and', 'CC'),
#     ('prayers', 'NNS'),
#     ('with', 'IN'),
#     ('the', 'DT'),
#     ('displaced', 'JJ'),
#     ('and', 'CC'),
#     ('the', 'DT'),
#     ('families', 'NNS'),
#     ('of', 'IN'),
#     ('those', 'DT'),
#     ('dead', 'JJ'),
#     ('and', 'CC'),
#     ('injured', 'JJ'),
#     ('.', '.')],
#    [('#', '#'), ('Balochistan', 'NNP')]]},
#  {'TweetID': '382827132931424256',
#   'Text': '#Earthquake at 50km WNW of Anchor Point, Alaska 2.8 M. Detph 79.6 Km. - 2013-09-27 21:01:48 UTC http://t.co/DsQsXpXJBE',
#   'POS': [[('#', '#'),
#     ('Earthquake', 'NNP'),
#     ('at', 'IN'),
#     ('50km', 'CD'),
#     ('WNW', 'NNP'),
#     ('of', 'IN'),
#     ('Anchor', 'NNP'),
#     ('Point', 'NNP'),
#     (',', ','),
#     ('Alaska', 'NNP'),
#     ('2.8', 'CD'),
#     ('M.', 'NNP'),
#     ('Detph', 'NNP'),
#     ('79.6', 'CD'),
#     ('Km', 'NNP'),
#     ('.', '.')],
#    [('-', ':'),
#     ('2013-09-27', 'JJ'),
#     ('21:01:48', 'CD'),
#     ('UTC', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/DsQsXpXJBE', 'NN')]]},
#  {'TweetID': '382827137423917056',
#   'Text': 'RT @AJStream: Following the earthquake in #Balochistan, the island that sprung up near #Gwadar has people tweeting - http://t.co/XxwAx5NSms',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('AJStream', 'NNP'),
#     (':', ':'),
#     ('Following', 'VBG'),
#     ('the', 'DT'),
#     ('earthquake', 'NN'),
#     ('in', 'IN'),
#     ('#', '#'),
#     ('Balochistan', 'NNP'),
#     (',', ','),
#     ('the', 'DT'),
#     ('island', 'NN'),
#     ('that', 'WDT'),
#     ('sprung', 'VBD'),
#     ('up', 'RP'),
#     ('near', 'RB'),
#     ('#', '#'),
#     ('Gwadar', 'NNP'),
#     ('has', 'VBZ'),
#     ('people', 'NNS'),
#     ('tweeting', 'VBG'),
#     ('-', ':'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/XxwAx5NSms', 'NN')]]},
#  {'TweetID': '382827140141826048',
#   'Text': 'how prepare are you? #earthquake http://t.co/ZbGSMiFpo2',
#   'POS': [[('how', 'WRB'),
#     ('prepare', 'NN'),
#     ('are', 'VBP'),
#     ('you', 'PRP'),
#     ('?', '.')],
#    [('#', '#'),
#     ('earthquake', 'NN'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/ZbGSMiFpo2', 'NN')]]},
#  {'TweetID': '382827149977079808',
#   'Text': 'RT @GFarooqi: Just returned from #Awaran Severely miserable condition of Earth Quake victims. No water, no food, no tents, no medical stillâ€¦',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('GFarooqi', 'NNP'),
#     (':', ':'),
#     ('Just', 'RB'),
#     ('returned', 'VBN'),
#     ('from', 'IN'),
#     ('#', '#'),
#     ('Awaran', 'NNP'),
#     ('Severely', 'NNP'),
#     ('miserable', 'JJ'),
#     ('condition', 'NN'),
#     ('of', 'IN'),
#     ('Earth', 'NNP'),
#     ('Quake', 'NNP'),
#     ('victims', 'NNS'),
#     ('.', '.')],
#    [('No', 'DT'),
#     ('water', 'NN'),
#     (',', ','),
#     ('no', 'DT'),
#     ('food', 'NN'),
#     (',', ','),
#     ('no', 'DT'),
#     ('tents', 'NNS'),
#     (',', ','),
#     ('no', 'DT'),
#     ('medical', 'JJ'),
#     ('stillâ€¦', 'NN')]]},
#  {'TweetID': '382827161679187969',
#   'Text': 'RT @Fariyalbad: ic of small island created near Gwadar after 7.8 #earthquake that rocked most parts of western Balochistan http://t.co/TDcUâ€¦',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('Fariyalbad', 'NNP'),
#     (':', ':'),
#     ('ic', 'NN'),
#     ('of', 'IN'),
#     ('small', 'JJ'),
#     ('island', 'NN'),
#     ('created', 'VBD'),
#     ('near', 'IN'),
#     ('Gwadar', 'NNP'),
#     ('after', 'IN'),
#     ('7.8', 'CD'),
#     ('#', '#'),
#     ('earthquake', 'NN'),
#     ('that', 'WDT'),
#     ('rocked', 'VBD'),
#     ('most', 'RBS'),
#     ('parts', 'NNS'),
#     ('of', 'IN'),
#     ('western', 'JJ'),
#     ('Balochistan', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/TDcUâ€¦', 'NN')]]},
#  {'TweetID': '382827172521443328',
#   'Text': 'USGS reports a M0.22 #earthquake 2km NE of Spanish Springs, Nevada on 10/1/13 @ 6:26:28 UTC http://t.co/ak2VeXioW2 #quake',
#   'POS': [[('USGS', 'NNP'),
#     ('reports', 'VBZ'),
#     ('a', 'DT'),
#     ('M0.22', 'NNP'),
#     ('#', '#'),
#     ('earthquake', 'NN'),
#     ('2km', 'CD'),
#     ('NE', 'NNP'),
#     ('of', 'IN'),
#     ('Spanish', 'JJ'),
#     ('Springs', 'NNP'),
#     (',', ','),
#     ('Nevada', 'NNP'),
#     ('on', 'IN'),
#     ('10/1/13', 'CD'),
#     ('@', 'JJ'),
#     ('6:26:28', 'CD'),
#     ('UTC', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/ak2VeXioW2', 'JJ'),
#     ('#', '#'),
#     ('quake', 'NN')]]},
#  {'TweetID': '382827173603590144',
#   'Text': 'ã€\x90#USGS #Breakingã€‘ M 1.3, 7km ENE of San Martin, California http://t.co/VZ2Lb5bZjO #PastHour #13 #earthquake #tsunami #prayfromjapan',
#   'POS': [[('ã€\x90', 'RB'),
#     ('#', '#'),
#     ('USGS', 'NNP'),
#     ('#', '#'),
#     ('Breakingã€', 'NNP'),
#     ('‘', 'NNP'),
#     ('M', 'NNP'),
#     ('1.3', 'CD'),
#     (',', ','),
#     ('7km', 'CD'),
#     ('ENE', 'NN'),
#     ('of', 'IN'),
#     ('San', 'NNP'),
#     ('Martin', 'NNP'),
#     (',', ','),
#     ('California', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/VZ2Lb5bZjO', 'JJ'),
#     ('#', '#'),
#     ('PastHour', 'NNP'),
#     ('#', '#'),
#     ('13', 'CD'),
#     ('#', '#'),
#     ('earthquake', 'NN'),
#     ('#', '#'),
#     ('tsunami', 'NN'),
#     ('#', '#'),
#     ('prayfromjapan', 'NN')]]},
#  {'TweetID': '382827174715469824',
#   'Text': 'RT @AnasMallick: #Earthquake survivors of Balochistan being shifted for Medical treatment by Pakistani ParaMilitary forces. http://t.co/6tYâ€¦',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('AnasMallick', 'NNP'),
#     (':', ':'),
#     ('#', '#'),
#     ('Earthquake', 'NNP'),
#     ('survivors', 'NNS'),
#     ('of', 'IN'),
#     ('Balochistan', 'NNP'),
#     ('being', 'VBG'),
#     ('shifted', 'VBN'),
#     ('for', 'IN'),
#     ('Medical', 'NNP'),
#     ('treatment', 'NN'),
#     ('by', 'IN'),
#     ('Pakistani', 'NNP'),
#     ('ParaMilitary', 'NNP'),
#     ('forces', 'NNS'),
#     ('.', '.')],
#    [('http', 'NN'), (':', ':'), ('//t.co/6tYâ€¦', 'NN')]]},
#  {'TweetID': '382827180725899264',
#   'Text': 'RT @AdilNajam: 7.9 #Earthquake hits Balochistan. We are a resilient people, but why must our resilience be tested so often! How I wish for â€¦',
#   'POS': [[('RT', 'NNP'),
#     ('@', 'NNP'),
#     ('AdilNajam', 'NNP'),
#     (':', ':'),
#     ('7.9', 'CD'),
#     ('#', '#'),
#     ('Earthquake', 'NNP'),
#     ('hits', 'NNS'),
#     ('Balochistan', 'NNP'),
#     ('.', '.')],
#    [('We', 'PRP'),
#     ('are', 'VBP'),
#     ('a', 'DT'),
#     ('resilient', 'JJ'),
#     ('people', 'NNS'),
#     (',', ','),
#     ('but', 'CC'),
#     ('why', 'WRB'),
#     ('must', 'MD'),
#     ('our', 'PRP$'),
#     ('resilience', 'NN'),
#     ('be', 'VB'),
#     ('tested', 'VBN'),
#     ('so', 'RB'),
#     ('often', 'RB'),
#     ('!', '.')],
#    [('How', 'WRB'),
#     ('I', 'PRP'),
#     ('wish', 'VBP'),
#     ('for', 'IN'),
#     ('â€¦', 'NN')]]},
#  {'TweetID': '382827187826466816',
#   'Text': 'ã€\x90#USGS #alertã€‘ M 2.9, Puerto Rico region: September 25, 2013 20:07:56 GMT http://t.co/0lJAJRDbwZ #earthquake #tsunami #prayfromjapan',
#   'POS': [[('ã€\x90', 'RB'),
#     ('#', '#'),
#     ('USGS', 'NNP'),
#     ('#', '#'),
#     ('alertã€', 'NN'),
#     ('‘', 'NNP'),
#     ('M', 'NNP'),
#     ('2.9', 'CD'),
#     (',', ','),
#     ('Puerto', 'NNP'),
#     ('Rico', 'NNP'),
#     ('region', 'NN'),
#     (':', ':'),
#     ('September', 'NNP'),
#     ('25', 'CD'),
#     (',', ','),
#     ('2013', 'CD'),
#     ('20:07:56', 'CD'),
#     ('GMT', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/0lJAJRDbwZ', 'JJ'),
#     ('#', '#'),
#     ('earthquake', 'NN'),
#     ('#', '#'),
#     ('tsunami', 'NN'),
#     ('#', '#'),
#     ('prayfromjapan', 'NN')]]},
#  {'TweetID': '382827194818363394',
#   'Text': '@NationalParty_ Did talked about the #earthquake affecteess #Awaran ?',
#   'POS': [[('@', 'JJ'),
#     ('NationalParty_', 'NNP'),
#     ('Did', 'NNP'),
#     ('talked', 'VBD'),
#     ('about', 'IN'),
#     ('the', 'DT'),
#     ('#', '#'),
#     ('earthquake', 'NN'),
#     ('affecteess', 'JJ'),
#     ('#', '#'),
#     ('Awaran', 'NNP'),
#     ('?', '.')]]},
#  {'TweetID': '382827203009855488',
#   'Text': 'My Misbah fan friend texted me that the new island should be named MisbahAbad #earthquake #Cricket',
#   'POS': [[('My', 'PRP$'),
#     ('Misbah', 'NNP'),
#     ('fan', 'NN'),
#     ('friend', 'NN'),
#     ('texted', 'VBD'),
#     ('me', 'PRP'),
#     ('that', 'IN'),
#     ('the', 'DT'),
#     ('new', 'JJ'),
#     ('island', 'NN'),
#     ('should', 'MD'),
#     ('be', 'VB'),
#     ('named', 'VBN'),
#     ('MisbahAbad', 'NNP'),
#     ('#', '#'),
#     ('earthquake', 'NN'),
#     ('#', '#'),
#     ('Cricket', 'NNP')]]},
#  {'TweetID': '382827205853597696',
#   'Text': 'ã€\x90#USGS #Breakingã€‘ M 6.1, 101km WSW of Puerto Madero, Mexico http://t.co/pTI4tUbte3 #PastHour #61 #earthquake #tsunami #prayfromjapan',
#   'POS': [[('ã€\x90', 'RB'),
#     ('#', '#'),
#     ('USGS', 'NNP'),
#     ('#', '#'),
#     ('Breakingã€', 'NNP'),
#     ('‘', 'NNP'),
#     ('M', 'NNP'),
#     ('6.1', 'CD'),
#     (',', ','),
#     ('101km', 'CD'),
#     ('WSW', 'NNP'),
#     ('of', 'IN'),
#     ('Puerto', 'NNP'),
#     ('Madero', 'NNP'),
#     (',', ','),
#     ('Mexico', 'NNP'),
#     ('http', 'NN'),
#     (':', ':'),
#     ('//t.co/pTI4tUbte3', 'JJ'),
#     ('#', '#'),
#     ('PastHour', 'NNP'),
#     ('#', '#'),
#     ('61', 'CD'),
#     ('#', '#'),
#     ('earthquake', 'NN'),
#     ('#', '#'),
#     ('tsunami', 'NN'),
#     ('#', '#'),
#     ('prayfromjapan', 'NN')]]},
#  ...]
