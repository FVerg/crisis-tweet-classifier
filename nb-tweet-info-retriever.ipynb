# %%
import twython
from twython import Twython
import pandas as pd
import json
import numpy as np
import time
import datetime as dt

from user_age import user_age
from is_geotagged import is_geotagged
from str_to_datetime import str_to_datetime

pd.options.mode.chained_assignment = None  # default='warn'

keys = json.load(open("keys.json"))

CONSUMER_KEY = keys['consumer_key']                 # Type your CONSUMER_KEY
CONSUMER_SECRET = keys['consumer_secret']           # Type your CONSUMER_SECRET
OAUTH_TOKEN = keys['access_token']                 # Type your OAUTH_TOKEN
OAUTH_TOKEN_SECRET = keys['access_token_secret']   # Type your OAUTH_TOKEN_SECRET

twitter = Twython(CONSUMER_KEY, CONSUMER_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET)

dataset = pd.read_csv('C:/dataset/2013_pakistan_eq.csv', header=0)

# Retrieving all tweet ids in order to use APIs to fetch all the informations we need on them

tweet_ids = dataset["tweet_id"]

# tweet_ids will be a Pandas.Series object
print(type(tweet_ids))

# Removing the apexes from each Tweet ID

for i in range(0, tweet_ids.size):
    tweet_ids[i] = tweet_ids[i].replace("'", "")

print("[DEBUG] Formatting tweets")

# Create a new DataFrame, initially containing just the IDs

# tweet_infos = pd.DataFrame(tweet_ids)

# List that will contain the new informations to add to the DataFrame tweet_infos

list_infos = []             # List that will contain the new informations

# Access to the informations of each tweet, retrieving them through Tweet ID
correctly_extracted = 0
not_available = 0
for id in tweet_ids:
    while True:
        try:
            tweet = twitter.show_status(id=id)
            list_infos.append({"Username": tweet['user']['name'],
                               "TweetID": id, "Followers": tweet['user']['followers_count'],
                               "Followed": tweet['user']['friends_count'], "TwitterAge": user_age(tweet['user']['created_at']),
                               "TotalTweets": tweet['user']['statuses_count'], "Verified": tweet['user']['verified'],
                               "Geotagged": is_geotagged(tweet), "nHashtags": len(tweet['entities']['hashtags']), "nURLs": len(tweet['entities']['urls']),
                               "nMentions": len(tweet['entities']['user_mentions']), "CreationTime": tweet['created_at']})
            correctly_extracted = correctly_extracted + 1
            print("[DEBUG] Found info for tweet: ", id, ". Added to list.")
            break
        except twython.exceptions.TwythonRateLimitError as e:
            # If we reach the limit of downloadable tweets in a time window, we wait 5 minutes and try again
            print(e)
            print("[DEBUG] Maximum number of tweets reached. Trying again in 5 mins...")
            print("[DEBUG]", correctly_extracted, "tweets have been correctly extracted")
            print("[DEBUG]", not_available,
                  "tweets have encountered problems during download (403, 404, ...)")
            for i in range(300):
                if i == 299:
                    print("[DEBUG]", 300-i, "second left...")
                else:
                    print("[DEBUG]", 300-i, "seconds left...")
                time.sleep(1)
            # break
        except twython.exceptions.TwythonError as e:
            # If other exceptions occurs (APIs return an unexpected HTTP response code) we print it
            # This box includes error like 404 - Not found, 403 - User suspended etc.
            print("[DEBUG]", e)
            not_available = not_available + 1
            break
# Out:
# <class 'pandas.core.series.Series'>
# [DEBUG] Formatting tweets
# [DEBUG] Found info for tweet:  382813388503412736 . Added to list.
# [DEBUG] Found info for tweet:  382813391435206659 . Added to list.
# [DEBUG] Found info for tweet:  382813401845485568 . Added to list.
# [DEBUG] Found info for tweet:  382813437513834497 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382813444011204608 . Added to list.
# [DEBUG] Found info for tweet:  382813445495586816 . Added to list.
# [DEBUG] Found info for tweet:  382813466014121984 . Added to list.
# [DEBUG] Found info for tweet:  382813467528282112 . Added to list.
# [DEBUG] Found info for tweet:  382813501489946624 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382813514881982464 . Added to list.
# [DEBUG] Found info for tweet:  382813518602313729 . Added to list.
# [DEBUG] Found info for tweet:  382813530396700672 . Added to list.
# [DEBUG] Found info for tweet:  382813532305096705 . Added to list.
# [DEBUG] Found info for tweet:  382813540366954497 . Added to list.
# [DEBUG] Found info for tweet:  382813540413095936 . Added to list.
# [DEBUG] Found info for tweet:  382813561875361792 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Found info for tweet:  382813587410259968 . Added to list.
# [DEBUG] Found info for tweet:  382813601024995328 . Added to list.
# [DEBUG] Found info for tweet:  382813620356534272 . Added to list.
# [DEBUG] Found info for tweet:  382813652752928768 . Added to list.
# [DEBUG] Found info for tweet:  382813700375474176 . Added to list.
# [DEBUG] Found info for tweet:  382813702132867072 . Added to list.
# [DEBUG] Found info for tweet:  382813719941484544 . Added to list.
# [DEBUG] Found info for tweet:  382813733623300096 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382813761330888704 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382813788832940033 . Added to list.
# [DEBUG] Found info for tweet:  382813812040409089 . Added to list.
# [DEBUG] Found info for tweet:  382813829719019521 . Added to list.
# [DEBUG] Found info for tweet:  382813848006180864 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382813873679896576 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Found info for tweet:  382813924208308224 . Added to list.
# [DEBUG] Found info for tweet:  382813932437917696 . Added to list.
# [DEBUG] Found info for tweet:  382813945913831424 . Added to list.
# [DEBUG] Found info for tweet:  382813996354510848 . Added to list.
# [DEBUG] Found info for tweet:  382814017099558912 . Added to list.
# [DEBUG] Found info for tweet:  382814060326043648 . Added to list.
# [DEBUG] Found info for tweet:  382814060385161216 . Added to list.
# [DEBUG] Found info for tweet:  382814062196703232 . Added to list.
# [DEBUG] Found info for tweet:  382814062704226304 . Added to list.
# [DEBUG] Found info for tweet:  382814074104328192 . Added to list.
# [DEBUG] Found info for tweet:  382814074439868419 . Added to list.
# [DEBUG] Found info for tweet:  382814086519869441 . Added to list.
# [DEBUG] Found info for tweet:  382814114860367872 . Added to list.
# [DEBUG] Found info for tweet:  382814115276025856 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), Sorry, you are not authorized to see this status.
# [DEBUG] Found info for tweet:  382814118056431616 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382814125899784192 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382814134032531456 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382814138235236352 . Added to list.
# [DEBUG] Found info for tweet:  382814139623931904 . Added to list.
# [DEBUG] Found info for tweet:  382814141620043776 . Added to list.
# [DEBUG] Found info for tweet:  382814144824479746 . Added to list.
# [DEBUG] Found info for tweet:  382814146620059648 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382814148851023872 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382814152969838592 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382814156857950208 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382814158682877952 . Added to list.
# [DEBUG] Found info for tweet:  382814164319993856 . Added to list.
# [DEBUG] Found info for tweet:  382814178768990208 . Added to list.
# [DEBUG] Found info for tweet:  382814179624628224 . Added to list.
# [DEBUG] Found info for tweet:  382814190421168128 . Added to list.
# [DEBUG] Found info for tweet:  382814241843343361 . Added to list.
# [DEBUG] Found info for tweet:  382814257760321538 . Added to list.
# [DEBUG] Found info for tweet:  382814286654865408 . Added to list.
# [DEBUG] Found info for tweet:  382814335048773632 . Added to list.
# [DEBUG] Found info for tweet:  382814341247938562 . Added to list.
# [DEBUG] Found info for tweet:  382814365323247617 . Added to list.
# [DEBUG] Found info for tweet:  382814369425285120 . Added to list.
# [DEBUG] Found info for tweet:  382814374018031616 . Added to list.
# [DEBUG] Found info for tweet:  382814414220824576 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382814450119876608 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), Sorry, you are not authorized to see this status.
# [DEBUG] Found info for tweet:  382814489831555072 . Added to list.
# [DEBUG] Found info for tweet:  382814490053451776 . Added to list.
# [DEBUG] Found info for tweet:  382814495527038976 . Added to list.
# [DEBUG] Found info for tweet:  382814514682413056 . Added to list.
# [DEBUG] Found info for tweet:  382814523507621888 . Added to list.
# [DEBUG] Found info for tweet:  382814530809511936 . Added to list.
# [DEBUG] Found info for tweet:  382814531753639936 . Added to list.
# [DEBUG] Found info for tweet:  382814538812641280 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Found info for tweet:  382814615500902400 . Added to list.
# [DEBUG] Found info for tweet:  382814617447436288 . Added to list.
# [DEBUG] Found info for tweet:  382814633213448192 . Added to list.
# [DEBUG] Found info for tweet:  382814634090037248 . Added to list.
# [DEBUG] Found info for tweet:  382814651580678144 . Added to list.
# [DEBUG] Found info for tweet:  382814668257263616 . Added to list.
# [DEBUG] Found info for tweet:  382814695113379840 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382814739367084032 . Added to list.
# [DEBUG] Found info for tweet:  382814746774626304 . Added to list.
# [DEBUG] Found info for tweet:  382814752591732736 . Added to list.
# [DEBUG] Found info for tweet:  382814766852358145 . Added to list.
# [DEBUG] Found info for tweet:  382814800163508224 . Added to list.
# [DEBUG] Found info for tweet:  382814800293543938 . Added to list.
# [DEBUG] Found info for tweet:  382814811999838208 . Added to list.
# [DEBUG] Found info for tweet:  382814827439071232 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382814858309140480 . Added to list.
# [DEBUG] Found info for tweet:  382814863774326784 . Added to list.
# [DEBUG] Found info for tweet:  382814873727410176 . Added to list.
# [DEBUG] Found info for tweet:  382814888776577024 . Added to list.
# [DEBUG] Found info for tweet:  382814901263015937 . Added to list.
# [DEBUG] Found info for tweet:  382814936030019584 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Found info for tweet:  382814942023262208 . Added to list.
# [DEBUG] Found info for tweet:  382814949988249600 . Added to list.
# [DEBUG] Found info for tweet:  382814975292481537 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382814998864478208 . Added to list.
# [DEBUG] Found info for tweet:  382815020603543552 . Added to list.
# [DEBUG] Found info for tweet:  382815028006514688 . Added to list.
# [DEBUG] Found info for tweet:  382815045748400128 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382815055781588992 . Added to list.
# [DEBUG] Found info for tweet:  382815067294543872 . Added to list.
# [DEBUG] Found info for tweet:  382815093714870272 . Added to list.
# [DEBUG] Found info for tweet:  382815104850329600 . Added to list.
# [DEBUG] Found info for tweet:  382815117575872513 . Added to list.
# [DEBUG] Found info for tweet:  382815134047272960 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382815139314937856 . Added to list.
# [DEBUG] Found info for tweet:  382815139994415104 . Added to list.
# [DEBUG] Found info for tweet:  382815140665491456 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382815170923610112 . Added to list.
# [DEBUG] Found info for tweet:  382815208005062656 . Added to list.
# [DEBUG] Found info for tweet:  382815219891712000 . Added to list.
# [DEBUG] Found info for tweet:  382815237940187136 . Added to list.
# [DEBUG] Found info for tweet:  382815263483506688 . Added to list.
# [DEBUG] Found info for tweet:  382815297347911680 . Added to list.
# [DEBUG] Found info for tweet:  382815302993842176 . Added to list.
# [DEBUG] Found info for tweet:  382815351211175936 . Added to list.
# [DEBUG] Found info for tweet:  382815369251282944 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382815393079111680 . Added to list.
# [DEBUG] Found info for tweet:  382815402826268672 . Added to list.
# [DEBUG] Found info for tweet:  382815408903843840 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382815450272649216 . Added to list.
# [DEBUG] Found info for tweet:  382815462645440512 . Added to list.
# [DEBUG] Found info for tweet:  382815466344816640 . Added to list.
# [DEBUG] Found info for tweet:  382815477837225984 . Added to list.
# [DEBUG] Found info for tweet:  382815486313906177 . Added to list.
# [DEBUG] Found info for tweet:  382815488935342082 . Added to list.
# [DEBUG] Found info for tweet:  382815509324263424 . Added to list.
# [DEBUG] Found info for tweet:  382815529486254080 . Added to list.
# [DEBUG] Found info for tweet:  382815535982858240 . Added to list.
# [DEBUG] Found info for tweet:  382815541372932096 . Added to list.
# [DEBUG] Found info for tweet:  382815548230221826 . Added to list.
# [DEBUG] Found info for tweet:  382815602164781056 . Added to list.
# [DEBUG] Found info for tweet:  382815604484620288 . Added to list.
# [DEBUG] Found info for tweet:  382815607491923968 . Added to list.
# [DEBUG] Found info for tweet:  382815624936050688 . Added to list.
# [DEBUG] Found info for tweet:  382815628953804800 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382815649736953856 . Added to list.
# [DEBUG] Found info for tweet:  382815654471938048 . Added to list.
# [DEBUG] Found info for tweet:  382815657425117184 . Added to list.
# [DEBUG] Found info for tweet:  382815658540818432 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382815716300177408 . Added to list.
# [DEBUG] Found info for tweet:  382815731915554816 . Added to list.
# [DEBUG] Found info for tweet:  382815751411089408 . Added to list.
# [DEBUG] Found info for tweet:  382815776425525248 . Added to list.
# [DEBUG] Found info for tweet:  382815780041404416 . Added to list.
# [DEBUG] Found info for tweet:  382815792200306688 . Added to list.
# [DEBUG] Found info for tweet:  382815813809364992 . Added to list.
# [DEBUG] Found info for tweet:  382815843706343424 . Added to list.
# [DEBUG] Found info for tweet:  382815846189768704 . Added to list.
# [DEBUG] Found info for tweet:  382815850040143872 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382815862509826048 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Found info for tweet:  382815904834539520 . Added to list.
# [DEBUG] Found info for tweet:  382815940720611328 . Added to list.
# [DEBUG] Found info for tweet:  382815962438713344 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Found info for tweet:  382816005744889857 . Added to list.
# [DEBUG] Found info for tweet:  382816039899521024 . Added to list.
# [DEBUG] Found info for tweet:  382816065270874112 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382816079367512064 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), Sorry, you are not authorized to see this status.
# [DEBUG] Found info for tweet:  382816095201001474 . Added to list.
# [DEBUG] Found info for tweet:  382816114889465856 . Added to list.
# [DEBUG] Found info for tweet:  382816126389866497 . Added to list.
# [DEBUG] Found info for tweet:  382816138763046912 . Added to list.
# [DEBUG] Found info for tweet:  382816167368196096 . Added to list.
# [DEBUG] Found info for tweet:  382816180055977984 . Added to list.
# [DEBUG] Found info for tweet:  382816197588168704 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382816204877885440 . Added to list.
# [DEBUG] Found info for tweet:  382816210012098560 . Added to list.
# [DEBUG] Found info for tweet:  382816216571604992 . Added to list.
# [DEBUG] Found info for tweet:  382816229137719296 . Added to list.
# [DEBUG] Found info for tweet:  382816229167099904 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382816284288643072 . Added to list.
# [DEBUG] Found info for tweet:  382816301028089856 . Added to list.
# [DEBUG] Found info for tweet:  382816317260066818 . Added to list.
# [DEBUG] Found info for tweet:  382816326265229312 . Added to list.
# [DEBUG] Found info for tweet:  382816331961077761 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), Sorry, you are not authorized to see this status.
# [DEBUG] Found info for tweet:  382816365205127168 . Added to list.
# [DEBUG] Found info for tweet:  382816386000502784 . Added to list.
# [DEBUG] Found info for tweet:  382816399183577088 . Added to list.
# [DEBUG] Found info for tweet:  382816420356030465 . Added to list.
# [DEBUG] Found info for tweet:  382816433455259648 . Added to list.
# [DEBUG] Found info for tweet:  382816452325019649 . Added to list.
# [DEBUG] Found info for tweet:  382816472713945088 . Added to list.
# [DEBUG] Found info for tweet:  382816510604898304 . Added to list.
# [DEBUG] Found info for tweet:  382816512249044992 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382816578271592448 . Added to list.
# [DEBUG] Found info for tweet:  382816597565382656 . Added to list.
# [DEBUG] Found info for tweet:  382816620055248896 . Added to list.
# [DEBUG] Found info for tweet:  382816628846895104 . Added to list.
# [DEBUG] Found info for tweet:  382816646769160192 . Added to list.
# [DEBUG] Found info for tweet:  382816648341630977 . Added to list.
# [DEBUG] Found info for tweet:  382816679132020736 . Added to list.
# [DEBUG] Found info for tweet:  382816685335801856 . Added to list.
# [DEBUG] Found info for tweet:  382816715907678209 . Added to list.
# [DEBUG] Found info for tweet:  382816752398528512 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382816763546587137 . Added to list.
# [DEBUG] Found info for tweet:  382816788473729024 . Added to list.
# [DEBUG] Found info for tweet:  382816798799704064 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), Sorry, you are not authorized to see this status.
# [DEBUG] Found info for tweet:  382816829875712000 . Added to list.
# [DEBUG] Found info for tweet:  382816842097516545 . Added to list.
# [DEBUG] Found info for tweet:  382816843850719232 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Found info for tweet:  382816850884960256 . Added to list.
# [DEBUG] Found info for tweet:  382816856631169024 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Twitter API returned a 403 (Forbidden), Sorry, you are not authorized to see this status.
# [DEBUG] Found info for tweet:  382816951141015552 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Found info for tweet:  382816958065815552 . Added to list.
# [DEBUG] Found info for tweet:  382816970250256384 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382816989795741696 . Added to list.
# [DEBUG] Found info for tweet:  382816993713213441 . Added to list.
# [DEBUG] Found info for tweet:  382817010331037696 . Added to list.
# [DEBUG] Found info for tweet:  382817013053149184 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), Sorry, you are not authorized to see this status.
# [DEBUG] Found info for tweet:  382817014873485313 . Added to list.
# [DEBUG] Found info for tweet:  382817042132258818 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382817065624543233 . Added to list.
# [DEBUG] Found info for tweet:  382817080698888192 . Added to list.
# [DEBUG] Found info for tweet:  382817085069737984 . Added to list.
# [DEBUG] Found info for tweet:  382817095710294016 . Added to list.
# [DEBUG] Found info for tweet:  382817097069244416 . Added to list.
# [DEBUG] Found info for tweet:  382817115780026369 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382817132859256832 . Added to list.
# [DEBUG] Found info for tweet:  382817147962925057 . Added to list.
# [DEBUG] Found info for tweet:  382817159321092096 . Added to list.
# [DEBUG] Found info for tweet:  382817160017772544 . Added to list.
# [DEBUG] Found info for tweet:  382817175712436224 . Added to list.
# [DEBUG] Found info for tweet:  382817190937763840 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Found info for tweet:  382817217185710080 . Added to list.
# [DEBUG] Found info for tweet:  382817224739680256 . Added to list.
# [DEBUG] Found info for tweet:  382817282247770112 . Added to list.
# [DEBUG] Found info for tweet:  382817283846209537 . Added to list.
# [DEBUG] Found info for tweet:  382817293912518656 . Added to list.
# [DEBUG] Found info for tweet:  382817340909682688 . Added to list.
# [DEBUG] Found info for tweet:  382817353882292224 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Found info for tweet:  382817400300658688 . Added to list.
# [DEBUG] Found info for tweet:  382817407091216386 . Added to list.
# [DEBUG] Found info for tweet:  382817422979260417 . Added to list.
# [DEBUG] Found info for tweet:  382817478541189120 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Found info for tweet:  382817502884945920 . Added to list.
# [DEBUG] Found info for tweet:  382817541351301120 . Added to list.
# [DEBUG] Found info for tweet:  382817567519154176 . Added to list.
# [DEBUG] Found info for tweet:  382817582266335232 . Added to list.
# [DEBUG] Found info for tweet:  382817615241957376 . Added to list.
# [DEBUG] Found info for tweet:  382817630614073346 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382817678903083008 . Added to list.
# [DEBUG] Found info for tweet:  382817718493138944 . Added to list.
# [DEBUG] Found info for tweet:  382817747765186560 . Added to list.
# [DEBUG] Found info for tweet:  382817794351714304 . Added to list.
# [DEBUG] Found info for tweet:  382817810939789312 . Added to list.
# [DEBUG] Found info for tweet:  382817828422033408 . Added to list.
# [DEBUG] Found info for tweet:  382817833874231296 . Added to list.
# [DEBUG] Found info for tweet:  382817848319410176 . Added to list.
# [DEBUG] Found info for tweet:  382817862349377537 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), Sorry, you are not authorized to see this status.
# [DEBUG] Twitter API returned a 403 (Forbidden), Sorry, you are not authorized to see this status.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382817970868588544 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382818006046212097 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382818065450151936 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), Sorry, you are not authorized to see this status.
# [DEBUG] Found info for tweet:  382818091605843969 . Added to list.
# [DEBUG] Found info for tweet:  382818101982953472 . Added to list.
# [DEBUG] Found info for tweet:  382818105329610752 . Added to list.
# [DEBUG] Found info for tweet:  382818128243085312 . Added to list.
# [DEBUG] Found info for tweet:  382818181821509632 . Added to list.
# [DEBUG] Found info for tweet:  382818189995827200 . Added to list.
# [DEBUG] Found info for tweet:  382818190318764032 . Added to list.
# [DEBUG] Found info for tweet:  382818191401299968 . Added to list.
# [DEBUG] Found info for tweet:  382818218240274432 . Added to list.
# [DEBUG] Found info for tweet:  382818238532308993 . Added to list.
# [DEBUG] Found info for tweet:  382818251467530240 . Added to list.
# [DEBUG] Found info for tweet:  382818251648282624 . Added to list.
# [DEBUG] Found info for tweet:  382818268131885056 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Twitter API returned a 403 (Forbidden), Sorry, you are not authorized to see this status.
# [DEBUG] Found info for tweet:  382818298846384128 . Added to list.
# [DEBUG] Found info for tweet:  382818299219673089 . Added to list.
# [DEBUG] Found info for tweet:  382818308208091136 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), Sorry, you are not authorized to see this status.
# [DEBUG] Found info for tweet:  382818341951254529 . Added to list.
# [DEBUG] Found info for tweet:  382818363480633344 . Added to list.
# [DEBUG] Found info for tweet:  382818377015640065 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382818398628884481 . Added to list.
# [DEBUG] Found info for tweet:  382818413627711490 . Added to list.
# [DEBUG] Found info for tweet:  382818497744490496 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), Sorry, you are not authorized to see this status.
# [DEBUG] Found info for tweet:  382818524965502976 . Added to list.
# [DEBUG] Found info for tweet:  382818525020045313 . Added to list.
# [DEBUG] Found info for tweet:  382818532578574336 . Added to list.
# [DEBUG] Found info for tweet:  382818547132801024 . Added to list.
# [DEBUG] Found info for tweet:  382818557643730944 . Added to list.
# [DEBUG] Found info for tweet:  382818560420360192 . Added to list.
# [DEBUG] Found info for tweet:  382818570058489857 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Twitter API returned a 403 (Forbidden), Sorry, you are not authorized to see this status.
# [DEBUG] Found info for tweet:  382818604695044097 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Found info for tweet:  382818613763112960 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382818652929544192 . Added to list.
# [DEBUG] Found info for tweet:  382818659909246976 . Added to list.
# [DEBUG] Found info for tweet:  382818672969920513 . Added to list.
# [DEBUG] Found info for tweet:  382818703777099777 . Added to list.
# [DEBUG] Found info for tweet:  382818707967578112 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382818716461068288 . Added to list.
# [DEBUG] Found info for tweet:  382818724408860672 . Added to list.
# [DEBUG] Found info for tweet:  382818735285080064 . Added to list.
# [DEBUG] Found info for tweet:  382818744356986880 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382818785037529088 . Added to list.
# [DEBUG] Found info for tweet:  382818795418419201 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Found info for tweet:  382818823092854784 . Added to list.
# [DEBUG] Found info for tweet:  382818823495102464 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), Sorry, you are not authorized to see this status.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Found info for tweet:  382818856621723648 . Added to list.
# [DEBUG] Found info for tweet:  382818863072960512 . Added to list.
# [DEBUG] Found info for tweet:  382818876301791232 . Added to list.
# [DEBUG] Found info for tweet:  382818877274861568 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Found info for tweet:  382818911332212736 . Added to list.
# [DEBUG] Found info for tweet:  382818933092261888 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382818961488097280 . Added to list.
# [DEBUG] Found info for tweet:  382818986829684736 . Added to list.
# [DEBUG] Found info for tweet:  382818992143867905 . Added to list.
# [DEBUG] Found info for tweet:  382818993813204993 . Added to list.
# [DEBUG] Found info for tweet:  382819043113046016 . Added to list.
# [DEBUG] Found info for tweet:  382819091054342144 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382819139858870272 . Added to list.
# [DEBUG] Found info for tweet:  382819199414177792 . Added to list.
# [DEBUG] Found info for tweet:  382819235749040129 . Added to list.
# [DEBUG] Found info for tweet:  382819259447267328 . Added to list.
# [DEBUG] Found info for tweet:  382819348764577792 . Added to list.
# [DEBUG] Found info for tweet:  382819349150461953 . Added to list.
# [DEBUG] Found info for tweet:  382819355035447296 . Added to list.
# [DEBUG] Found info for tweet:  382819355571937281 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382819389768097792 . Added to list.
# [DEBUG] Found info for tweet:  382819401092706304 . Added to list.
# [DEBUG] Found info for tweet:  382819416033214464 . Added to list.
# [DEBUG] Found info for tweet:  382819416959758338 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382819453362130944 . Added to list.
# [DEBUG] Found info for tweet:  382819460484067328 . Added to list.
# [DEBUG] Found info for tweet:  382819486929526784 . Added to list.
# [DEBUG] Found info for tweet:  382819489512828928 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382819534685491200 . Added to list.
# [DEBUG] Found info for tweet:  382819534761369600 . Added to list.
# [DEBUG] Found info for tweet:  382819537588326400 . Added to list.
# [DEBUG] Found info for tweet:  382819555363414018 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Found info for tweet:  382819579510403072 . Added to list.
# [DEBUG] Found info for tweet:  382819616265084928 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382819645721690113 . Added to list.
# [DEBUG] Found info for tweet:  382819649781764096 . Added to list.
# [DEBUG] Found info for tweet:  382819652004352000 . Added to list.
# [DEBUG] Found info for tweet:  382819657843220480 . Added to list.
# [DEBUG] Found info for tweet:  382819659411509249 . Added to list.
# [DEBUG] Found info for tweet:  382819696611188736 . Added to list.
# [DEBUG] Found info for tweet:  382819700377264129 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382819713413152769 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382819728919523329 . Added to list.
# [DEBUG] Found info for tweet:  382819779918065664 . Added to list.
# [DEBUG] Found info for tweet:  382819798436290560 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  
. Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382820501821067265 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382820554186981376 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382820573673320448 . Added to list.
# [DEBUG] Found info for tweet:  382820590014693377 . Added to list.
# [DEBUG] Found info for tweet:  382820595391418368 . Added to list.
# [DEBUG] Found info for tweet:  382820720708833280 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Found info for tweet:  382820878464983040 . Added to list.
# [DEBUG] Found info for tweet:  382820883040960512 . Added to list.
# [DEBUG] Found info for tweet:  382820885280747520 . Added to list.
# [DEBUG] Found info for tweet:  382820886296145920 . Added to list.
# [DEBUG] Found info for tweet:  382820887529271296 . Added to list.
# [DEBUG] Found info for tweet:  382820893656764416 . Added to list.
# [DEBUG] Found info for tweet:  382820917702713344 . Added to list.
# [DEBUG] Found info for tweet:  382820921540476928 . Added to list.
# [DEBUG] Found info for tweet:  382820955682115585 . Added to list.
# [DEBUG] Found info for tweet:  382820963861004288 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382820983347761152 . Added to list.
# [DEBUG] Found info for tweet:  382821025354108928 . Added to list.
# [DEBUG] Found info for tweet:  382821063916138497 . Added to list.
# [DEBUG] Found info for tweet:  382821085013868544 . Added to list.
# [DEBUG] Found info for tweet:  382821090160308224 . Added to list.
# [DEBUG] Found info for tweet:  382821091774705666 . Added to list.
# [DEBUG] Found info for tweet:  382821132958572545 . Added to list.
# [DEBUG] Found info for tweet:  382821133973991424 . Added to list.
# [DEBUG] Found info for tweet:  382821134129180673 . Added to list.
# [DEBUG] Found info for tweet:  382821134179110912 . Added to list.
# [DEBUG] Found info for tweet:  382821174960717825 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382821205574946816 . Added to list.
# [DEBUG] Found info for tweet:  382821213820944384 . Added to list.
# [DEBUG] Found info for tweet:  382821223081586688 . Added to list.
# [DEBUG] Found info for tweet:  382821232032219136 . Added to list.
# [DEBUG] Found info for tweet:  382821252731109377 . Added to list.
# [DEBUG] Found info for tweet:  382821274344386560 . Added to list.
# [DEBUG] Found info for tweet:  382821278589394945 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Found info for tweet:  382821327062589440 . Added to list.
# [DEBUG] Found info for tweet:  382821330787524608 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382821366077992960 . Added to list.
# [DEBUG] Found info for tweet:  382821401637695488 . Added to list.
# [DEBUG] Found info for tweet:  382821409103572992 . Added to list.
# [DEBUG] Found info for tweet:  382821410076639232 . Added to list.
# [DEBUG] Found info for tweet:  382821445631356928 . Added to list.
# [DEBUG] Found info for tweet:  382821448697384960 . Added to list.
# [DEBUG] Found info for tweet:  382821473083064320 . Added to list.
# [DEBUG] Found info for tweet:  382821502250270720 . Added to list.
# [DEBUG] Found info for tweet:  382821548920700928 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Found info for tweet:  382821588863029248 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382821630965075968 . Added to list.
# [DEBUG] Found info for tweet:  382821653098409984 . Added to list.
# [DEBUG] Found info for tweet:  382821678771761153 . Added to list.
# [DEBUG] Found info for tweet:  382821704713527297 . Added to list.
# [DEBUG] Found info for tweet:  382821717301010432 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382821753694990336 . Added to list.
# [DEBUG] Found info for tweet:  382821772698984448 . Added to list.
# [DEBUG] Found info for tweet:  382821812012216320 . Added to list.
# [DEBUG] Found info for tweet:  382821843012308992 . Added to list.
# [DEBUG] Found info for tweet:  382821844107407360 . Added to list.
# [DEBUG] Found info for tweet:  382821853745516544 . Added to list.
# [DEBUG] Found info for tweet:  382821855024799744 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382821952085176321 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), Sorry, you are not authorized to see this status.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Twitter API returned a 403 (Forbidden), Sorry, you are not authorized to see this status.
# [DEBUG] Found info for tweet:  382821969093484544 . Added to list.
# ...
# [DEBUG] Found info for tweet:  382835307730567169 . Added to list.
# [DEBUG] Found info for tweet:  382835308217118720 . Added to list.
# [DEBUG] Found info for tweet:  382835310352420864 . Added to list.
# [DEBUG] Found info for tweet:  382835318841298944 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Found info for tweet:  382835377788035074 . Added to list.
# [DEBUG] Found info for tweet:  382835409358553088 . Added to list.
# [DEBUG] Found info for tweet:  382835418653151232 . Added to list.
# [DEBUG] Found info for tweet:  382835425867751424 . Added to list.
# [DEBUG] Found info for tweet:  382835427154997248 . Added to list.
# [DEBUG] Found info for tweet:  382835466095329280 . Added to list.
# [DEBUG] Found info for tweet:  382835466141437952 . Added to list.
# [DEBUG] Found info for tweet:  382835467357814784 . Added to list.
# [DEBUG] Found info for tweet:  382835479814492160 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382835488731975680 . Added to list.
# [DEBUG] Found info for tweet:  382835495174037504 . Added to list.
# [DEBUG] Found info for tweet:  382835526648098816 . Added to list.
# [DEBUG] Found info for tweet:  382835554397589504 . Added to list.
# [DEBUG] Found info for tweet:  382835569912737792 . Added to list.
# [DEBUG] Found info for tweet:  382835582595919872 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382835612673642496 . Added to list.
# [DEBUG] Found info for tweet:  382835613960896512 . Added to list.
# [DEBUG] Found info for tweet:  382835614820745216 . Added to list.
# [DEBUG] Found info for tweet:  382835615349604352 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382835676779413505 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382835715136323584 . Added to list.
# [DEBUG] Found info for tweet:  382835718650744833 . Added to list.
# [DEBUG] Found info for tweet:  382835725437136898 . Added to list.
# [DEBUG] Found info for tweet:  382835732886585344 . Added to list.
# [DEBUG] Found info for tweet:  382835733658345472 . Added to list.
# [DEBUG] Found info for tweet:  382835734572699648 . Added to list.
# [DEBUG] Found info for tweet:  382835741526470656 . Added to list.
# [DEBUG] Found info for tweet:  382835743896240128 . Added to list.
# [DEBUG] Found info for tweet:  382835746778124288 . Added to list.
# [DEBUG] Found info for tweet:  382835751185940480 . Added to list.
# [DEBUG] Found info for tweet:  382835754302308353 . Added to list.
# [DEBUG] Found info for tweet:  382835779392651264 . Added to list.
# [DEBUG] Found info for tweet:  382835784673288192 . Added to list.
# [DEBUG] Found info for tweet:  382835790444630018 . Added to list.
# [DEBUG] Found info for tweet:  382835814918782976 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382835871919001601 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), Sorry, you are not authorized to see this status.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382835908330139648 . Added to list.
# [DEBUG] Found info for tweet:  382835913610780673 . Added to list.
# [DEBUG] Found info for tweet:  382835928265670656 . Added to list.
# [DEBUG] Found info for tweet:  382835950831017984 . Added to list.
# [DEBUG] Found info for tweet:  382835955167551489 . Added to list.
# [DEBUG] Found info for tweet:  382835984637112320 . Added to list.
# [DEBUG] Found info for tweet:  382836020552929280 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382836049472262144 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382836063871311872 . Added to list.
# [DEBUG] Found info for tweet:  382836065666482176 . Added to list.
# [DEBUG] Found info for tweet:  382836073879326720 . Added to list.
# [DEBUG] Found info for tweet:  382836097358643201 . Added to list.
# [DEBUG] Found info for tweet:  382836107895119872 . Added to list.
# [DEBUG] Found info for tweet:  382836120397959168 . Added to list.
# [DEBUG] Found info for tweet:  382836123174985728 . Added to list.
# [DEBUG] Found info for tweet:  382836129026039808 . Added to list.
# [DEBUG] Found info for tweet:  382836134528573441 . Added to list.
# [DEBUG] Found info for tweet:  382836142510710784 . Added to list.
# [DEBUG] Found info for tweet:  382836143777406976 . Added to list.
# [DEBUG] Found info for tweet:  382836160160333824 . Added to list.
# [DEBUG] Found info for tweet:  382836161086910465 . Added to list.
# [DEBUG] Found info for tweet:  382836168431120384 . Added to list.
# [DEBUG] Found info for tweet:  382836172827144192 . Added to list.
# [DEBUG] Found info for tweet:  382836180070727680 . Added to list.
# [DEBUG] Found info for tweet:  382836185674309632 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382836196944404480 . Added to list.
# [DEBUG] Found info for tweet:  382836200286871552 . Added to list.
# [DEBUG] Found info for tweet:  382836203109613569 . Added to list.
# [DEBUG] Found info for tweet:  382836208088666112 . Added to list.
# [DEBUG] Found info for tweet:  382836208155754496 . Added to list.
# [DEBUG] Found info for tweet:  382836234814369792 . Added to list.
# [DEBUG] Found info for tweet:  382836237888790529 . Added to list.
# [DEBUG] Found info for tweet:  382836240057262082 . Added to list.
# [DEBUG] Found info for tweet:  382836250467528704 . Added to list.
# [DEBUG] Found info for tweet:  382836250794672128 . Added to list.
# [DEBUG] Found info for tweet:  382836256859627521 . Added to list.
# [DEBUG] Found info for tweet:  382836263696748544 . Added to list.
# [DEBUG] Found info for tweet:  382836264317497344 . Added to list.
# [DEBUG] Found info for tweet:  382836279315939328 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382836292452491265 . Added to list.
# [DEBUG] Found info for tweet:  382836313562435584 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382836322995408897 . Added to list.
# [DEBUG] Found info for tweet:  382836332638527488 . Added to list.
# [DEBUG] Found info for tweet:  382836341546819584 . Added to list.
# [DEBUG] Found info for tweet:  382836357879435264 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382836458626641920 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382836471087906819 . Added to list.
# [DEBUG] Found info for tweet:  382836475781316610 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382836486011224064 . Added to list.
# [DEBUG] Found info for tweet:  382836487064006657 . Added to list.
# [DEBUG] Found info for tweet:  382836495943335937 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382836521227026432 . Added to list.
# [DEBUG] Found info for tweet:  382836524947345408 . Added to list.
# [DEBUG] Found info for tweet:  382836533276844032 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Found info for tweet:  382836550423154688 . Added to list.
# [DEBUG] Found info for tweet:  382836555997396992 . Added to list.
# [DEBUG] Found info for tweet:  382836561743593472 . Added to list.
# [DEBUG] Found info for tweet:  382836569742118912 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382836574175502336 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382836639502200832 . Added to list.
# [DEBUG] Found info for tweet:  382836649521995776 . Added to list.
# [DEBUG] Found info for tweet:  382836685257453568 . Added to list.
# [DEBUG] Found info for tweet:  382836685656305664 . Added to list.
# [DEBUG] Found info for tweet:  382836697630654464 . Added to list.
# [DEBUG] Found info for tweet:  382836701371965441 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), Sorry, you are not authorized to see this status.
# [DEBUG] Found info for tweet:  382836715607441409 . Added to list.
# [DEBUG] Found info for tweet:  382836736595722240 . Added to list.
# [DEBUG] Found info for tweet:  382836738521329664 . Added to list.
# [DEBUG] Found info for tweet:  382836752941322240 . Added to list.
# [DEBUG] Found info for tweet:  382836757927981056 . Added to list.
# [DEBUG] Found info for tweet:  382836771584634880 . Added to list.
# [DEBUG] Found info for tweet:  382836782888280064 . Added to list.
# [DEBUG] Found info for tweet:  382836815616802816 . Added to list.
# [DEBUG] Found info for tweet:  382836823040335873 . Added to list.
# [DEBUG] Found info for tweet:  382836831576158208 . Added to list.
# [DEBUG] Found info for tweet:  382836834620805121 . Added to list.
# [DEBUG] Found info for tweet:  382836834914426881 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382836862546493440 . Added to list.
# [DEBUG] Found info for tweet:  382836873820778496 . Added to list.
# [DEBUG] Found info for tweet:  382836884126183425 . Added to list.
# [DEBUG] Found info for tweet:  382836891944357888 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382836898974035969 . Added to list.
# [DEBUG] Found info for tweet:  382836912069050368 . Added to list.
# [DEBUG] Found info for tweet:  382836957916573698 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382836962047963136 . Added to list.
# [DEBUG] Found info for tweet:  382836963964747776 . Added to list.
# [DEBUG] Found info for tweet:  382836979164905472 . Added to list.
# [DEBUG] Found info for tweet:  382836979466903552 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382837009577832449 . Added to list.
# [DEBUG] Found info for tweet:  382837010882240512 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Found info for tweet:  382837027760504832 . Added to list.
# [DEBUG] Found info for tweet:  382837030662598656 . Added to list.
# [DEBUG] Found info for tweet:  382837032612950016 . Added to list.
# [DEBUG] Found info for tweet:  382837044109537280 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382837053022429185 . Added to list.
# [DEBUG] Found info for tweet:  382837082202177536 . Added to list.
# [DEBUG] Found info for tweet:  382837087495815168 . Added to list.
# [DEBUG] Found info for tweet:  382837106491412480 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382837129753018368 . Added to list.
# [DEBUG] Found info for tweet:  382837135822577664 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), Sorry, you are not authorized to see this status.
# [DEBUG] Found info for tweet:  382837156487524352 . Added to list.
# [DEBUG] Found info for tweet:  382837177484210176 . Added to list.
# [DEBUG] Found info for tweet:  382837191509942272 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382837200976887808 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Found info for tweet:  382837206093553664 . Added to list.
# [DEBUG] Found info for tweet:  382837214042132480 . Added to list.
# [DEBUG] Found info for tweet:  382837272996884480 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), Sorry, you are not authorized to see this status.
# [DEBUG] Found info for tweet:  382837286297415680 . Added to list.
# [DEBUG] Found info for tweet:  382837290029957120 . Added to list.
# [DEBUG] Found info for tweet:  382837300935131136 . Added to list.
# [DEBUG] Found info for tweet:  382837306651983872 . Added to list.
# [DEBUG] Found info for tweet:  382837306920423426 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382837314747400192 . Added to list.
# [DEBUG] Found info for tweet:  382837321294286849 . Added to list.
# [DEBUG] Found info for tweet:  382837343792529408 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Found info for tweet:  382837378953781248 . Added to list.
# [DEBUG] Found info for tweet:  382837388764250112 . Added to list.
# [DEBUG] Found info for tweet:  382837394757517313 . Added to list.
# [DEBUG] Found info for tweet:  382837403402002433 . Added to list.
# [DEBUG] Found info for tweet:  382837411496992768 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382837428857221120 . Added to list.
# [DEBUG] Found info for tweet:  382837439435669504 . Added to list.
# [DEBUG] Found info for tweet:  382837443826679808 . Added to list.
# [DEBUG] Found info for tweet:  382837450076217344 . Added to list.
# [DEBUG] Found info for tweet:  382837466874785792 . Added to list.
# [DEBUG] Found info for tweet:  382837479147335681 . Added to list.
# [DEBUG] Found info for tweet:  382837486143041536 . Added to list.
# [DEBUG] Found info for tweet:  382837489897316352 . Added to list.
# [DEBUG] Found info for tweet:  382837500374294528 . Added to list.
# [DEBUG] Found info for tweet:  382837518955065344 . Added to list.
# [DEBUG] Found info for tweet:  382837519861051392 . Added to list.
# [DEBUG] Found info for tweet:  382837523417821185 . Added to list.
# [DEBUG] Found info for tweet:  382837533391851520 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382837568527560704 . Added to list.
# [DEBUG] Found info for tweet:  382837583362809856 . Added to list.
# [DEBUG] Found info for tweet:  382837605697474560 . Added to list.
# [DEBUG] Found info for tweet:  382837614610358272 . Added to list.
# [DEBUG] Found info for tweet:  382837614836858880 . Added to list.
# [DEBUG] Found info for tweet:  382837626702938112 . Added to list.
# [DEBUG] Found info for tweet:  382837627281354754 . Added to list.
# [DEBUG] Found info for tweet:  382814190421168128 . Added to list.
# [DEBUG] Found info for tweet:  382830219968909312 . Added to list.
# [DEBUG] Found info for tweet:  382833545179574272 . Added to list.
# [DEBUG] Found info for tweet:  382830434167439360 . Added to list.
# [DEBUG] Found info for tweet:  382818863072960512 . Added to list.
# [DEBUG] Found info for tweet:  382837135822577664 . Added to list.
# [DEBUG] Twitter API returned a 403 (Forbidden), User has been suspended.
# [DEBUG] Found info for tweet:  382836020552929280 . Added to list.
# [DEBUG] Found info for tweet:  382830606402351105 . Added to list.
# [DEBUG] Found info for tweet:  382817567519154176 . Added to list.
# [DEBUG] Twitter API returned a 404 (Not Found), No status found with that ID.
# [DEBUG] Found info for tweet:  382827962930069504 . Added to list.
# [DEBUG] Found info for tweet:  382827662109986816 . Added to list.

# %%
print("[DEBUG] calculating age of the tweet")
for item in list_infos:
    creation_time = str_to_datetime(item["CreationTime"])
    delta_time = dt.datetime.now() - creation_time
    item["DeltaTime"] = str(delta_time)

print("[DEBUG]", correctly_extracted, "tweets have been correctly extracted")
print("[DEBUG]", not_available,
      "tweets have encountered problems during download (403, 404, ...)")


# Save tweets and their metadata into a new Dataframe
meta_tweets = pd.DataFrame(list_infos)

# Set the index (Tweet ID)
meta_tweets = meta_tweets.set_index('TweetID')

# Extract the column names from the DataFrame
col_names = list(meta_tweets.columns.values)
# Out:
# [DEBUG] calculating age of the tweet
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-27fe83c5353b> in <module>()
#       1 print("[DEBUG] calculating age of the tweet")
#       2 for item in list_infos:
# ----> 3     creation_time = str_to_datetime(item["CreationTime"])
#       4     delta_time = dt.datetime.now() - creation_time
#       5     item["DeltaTime"] = str(delta_time)
#
# C:\git\crisis-tweet-classifier\str_to_datetime.py in str_to_datetime(str_time)
#       6
#       7 def str_to_datetime(str_time):
# ----> 8     date_and_time = []
#       9     # Splitting the string to extract separately date and time
#      10     # Structure: DayOfWeek Month Day Hour +0000 Year
#
# NameError: name 'words' is not defined
