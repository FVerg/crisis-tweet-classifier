# %%
import pandas as pd

dataset = pd.read_csv("C:/dataset/2013_pakistan_eq_metadata.csv", header=0)

# %%
dataset
# Out:
#                  TweetID                    CreationTime  Followed  Followers  \
# 0     382813388503412736  Wed Sep 25 10:26:38 +0000 2013       525        500
# 1     382813391435206659  Wed Sep 25 10:26:39 +0000 2013       499       2537
# 2     382813401845485568  Wed Sep 25 10:26:41 +0000 2013       236        220
# 3     382813437513834497  Wed Sep 25 10:26:50 +0000 2013      4197       7605
# 4     382813444011204608  Wed Sep 25 10:26:52 +0000 2013       273        116
# 5     382813445495586816  Wed Sep 25 10:26:52 +0000 2013       332        519
# 6     382813466014121984  Wed Sep 25 10:26:57 +0000 2013       395      12480
# 7     382813467528282112  Wed Sep 25 10:26:57 +0000 2013      2105       1032
# 8     382813501489946624  Wed Sep 25 10:27:05 +0000 2013       154         62
# 9     382813514881982464  Wed Sep 25 10:27:08 +0000 2013        44       1910
# 10    382813518602313729  Wed Sep 25 10:27:09 +0000 2013       857      12254
# ...
